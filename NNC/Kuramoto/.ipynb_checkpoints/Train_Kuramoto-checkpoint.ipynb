# %%
import numpy as np
import pdb
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '../..')) 
sys.path.append(project_root)  # Add folder_a to sys.path
sys.path.append(os.path.join(project_root, '../..', 'Networks'))  # Add folder_b to sys.path
import matplotlib.pyplot as plt
import torch
import torch.optim.swa_utils as swa_utils

from torch import nn
import copy

from torch import profiler
from tqdm import tqdm
import numpy as np

import pdb
import torchsde
from Networks.utils import get_gpu_memory,objective,update_ema, adj_lattice, criticalK, order_param,  load_clean_state_dict, sample_kuramoto,loss_compute_kur,save_model
from helpers import  KuramotoHyperUniversal,  find_params
import psutil
from adabelief_pytorch import AdaBelief
import gc
from IPython.display import clear_output

is_cuda = torch.cuda.is_available()
device = 'cuda' if is_cuda else 'cpu'
#device = 'cpu'
if not is_cuda:
    print("Warning: CUDA not available; falling back to CPU but this is likely to be very slow.")
gc.collect()  
torch.cuda.empty_cache()
path=os.path.abspath(os.getcwd())
print(get_gpu_memory())
# Out:
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 20583.875, 'used_memory': 3980.125}]

# %%
state_size=64

batch_size=4*256
weight=10**(-4)
scale=5
scale_kin=5

Astored=adj_lattice(state_size, "erdos", 0.3)


Kcrit, L=criticalK(Astored,state_size, scale)
Kcrit = 0.01* Kcrit

# %store  Astored
A=torch.tensor(Astored).to(torch.float32).to(device)
L=torch.tensor(L).to(torch.float32).to(device)

print(get_gpu_memory())


print(Kcrit)
# Out:
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 20376.1875, 'used_memory': 4187.8125}]
# 0.841310456374586

# %%
global_perf=[]
global_eperf=[]
global_stperf=[]
global_param=[]

dist = torch.distributions.Normal(0, 1)
iter = 5000
t_size=32
    
t_total=1

t = np.linspace(0, iter, iter)

ts_exp = torch.linspace(0, t_total, t_size).to(device)

for layers in range(3,5):
    learning_rate=0.0001

    gamma=0.999
  
    skip=False
    strategy="tHNC"
   
    SML= KuramotoHyperUniversal(batch_size, state_size, Kcrit,A, layers,skip,strategy,device).to(device)
 
    alpha=0.995
    params=find_params(SML)
    controller_optimizer = torch.optim.AdamW(params, lr=learning_rate,  weight_decay=0.0, amsgrad=False)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(controller_optimizer, gamma=gamma)
    

    perf=[]
    eperf=[]
    stperf=[]
    erpe=[]
    orpam=[]

    
    ema_model = copy.deepcopy(SML)
    ema_loss=0

    score=1000000
    
    t = np.linspace(0, iter, iter) 
    
    orparam=0
    
    
    for j in tqdm(range(iter)):
        
        freqs, ys_exp= sample_kuramoto(state_size,batch_size, dist, scale, scale_kin, device)

        SML.freqs=freqs

        ys_tray = torchsde.sdeint_adjoint(SML, ys_exp, ts_exp,method='reversible_heun', dt=ts_exp[1]-ts_exp[0],
                                     adjoint_method='adjoint_reversible_heun',)
    
        loss, ste_loss, logtrick=loss_compute_kur(ys_tray, state_size ,batch_size,weight,A)
        
        print("order parameter")
        ord_param=order_param(ys_tray[-1,:,0:state_size],L)
        print(ord_param)
    
        logtrick.backward()
        print("total loss")
        print(loss)
 

        controller_optimizer.step()
        controller_optimizer.zero_grad(set_to_none=True)
        scheduler.step()
        update_ema(SML, ema_model, alpha)
        print(get_gpu_memory())
        
        if j==0:
            ema_loss=loss.cpu().detach().numpy()  
        else:
            ema_loss=ema_loss*alpha+loss.cpu().detach().numpy()*(1-alpha)

       
        score= save_model(score, ema_loss, ema_model, SML, path,strategy,layers)


        perf.append(loss.cpu().detach().numpy())
        eperf.append(ema_loss)
        stperf.append(ste_loss.cpu().detach().numpy())
        orpam.append(ord_param.cpu().detach().numpy())
      
        gc.collect()
        
        torch.cuda.empty_cache()
        if j>100 and j%500==0:
                clear_output(wait=False) 
        del ys_tray
        
    global_perf.append(perf)
    global_eperf.append(eperf)
    

    global_stperf.append(stperf)
    global_param.append(orpam)

    
    with torch.no_grad():
        torch.cuda.empty_cache()
    gc.collect()
# Out:
# /home/qtomcat/anaconda3/lib/python3.12/site-packages/hypernn/torch/utils.py:35: FutureWarning: We've integrated functorch into PyTorch. As the final step of the integration, `functorch.make_functional` is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use `torch.func.functional_call` instead; see the PyTorch 2.0 release notes and/or the `torch.func` migration guide for more details https://pytorch.org/docs/main/func.migrating.html
#   _functional, named_params = make_functional(module)
#   0%|          | 0/5000 [00:00<?, ?it/s]
# order parameter
# tensor(0.9777, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 1/5000 [00:00<55:19,  1.51it/s]
# total loss
# tensor(81.5163, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19493.1875, 'used_memory': 5070.8125}]
# model saved
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 2/5000 [00:01<46:02,  1.81it/s]
# total loss
# tensor(81.2597, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19459.1875, 'used_memory': 5104.8125}]
# model saved
# order parameter
# tensor(0.9779, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 3/5000 [00:01<43:43,  1.91it/s]
# total loss
# tensor(80.8930, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.3125, 'used_memory': 5102.6875}]
# model saved
# order parameter
# tensor(0.9776, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 4/5000 [00:02<42:12,  1.97it/s]
# total loss
# tensor(81.6549, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.3125, 'used_memory': 5102.6875}]
# order parameter
# tensor(0.9774, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 5/5000 [00:02<41:04,  2.03it/s]
# total loss
# tensor(82.6100, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19463.1875, 'used_memory': 5100.8125}]
# order parameter
# tensor(0.9776, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 6/5000 [00:03<40:43,  2.04it/s]
# total loss
# tensor(81.8437, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.1875, 'used_memory': 5102.8125}]
# order parameter
# tensor(0.9774, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 7/5000 [00:03<39:59,  2.08it/s]
# total loss
# tensor(82.6366, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.375, 'used_memory': 5102.625}]
# order parameter
# tensor(0.9773, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 8/5000 [00:03<39:38,  2.10it/s]
# total loss
# tensor(82.7730, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.375, 'used_memory': 5102.625}]
# order parameter
# tensor(0.9775, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 9/5000 [00:04<39:53,  2.09it/s]
# total loss
# tensor(82.2556, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.5, 'used_memory': 5102.5}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 10/5000 [00:04<39:51,  2.09it/s]
# total loss
# tensor(81.2981, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19461.875, 'used_memory': 5102.125}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 11/5000 [00:05<39:40,  2.10it/s]
# total loss
# tensor(81.2350, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19482.1875, 'used_memory': 5081.8125}]
# order parameter
# tensor(0.9776, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 12/5000 [00:05<39:28,  2.11it/s]
# total loss
# tensor(81.7058, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19482.1875, 'used_memory': 5081.8125}]
# order parameter
# tensor(0.9777, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 13/5000 [00:06<40:04,  2.07it/s]
# total loss
# tensor(81.3709, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19482.125, 'used_memory': 5081.875}]
# order parameter
# tensor(0.9774, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 14/5000 [00:06<40:06,  2.07it/s]
# total loss
# tensor(82.6697, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.125, 'used_memory': 5089.875}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 15/5000 [00:07<39:43,  2.09it/s]
# total loss
# tensor(81.0929, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.125, 'used_memory': 5089.875}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 16/5000 [00:07<39:28,  2.10it/s]
# total loss
# tensor(81.4000, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.125, 'used_memory': 5089.875}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 17/5000 [00:08<39:21,  2.11it/s]
# total loss
# tensor(81.2552, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.125, 'used_memory': 5089.875}]
# order parameter
# tensor(0.9776, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 18/5000 [00:08<39:15,  2.11it/s]
# total loss
# tensor(81.9667, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.1875, 'used_memory': 5089.8125}]
# order parameter
# tensor(0.9781, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 19/5000 [00:09<39:28,  2.10it/s]
# total loss
# tensor(80.2347, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.1875, 'used_memory': 5089.8125}]
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 20/5000 [00:09<39:21,  2.11it/s]
# total loss
# tensor(81.1219, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19476.1875, 'used_memory': 5087.8125}]
# order parameter
# tensor(0.9780, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 21/5000 [00:10<39:13,  2.12it/s]
# total loss
# tensor(80.4466, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19476.1875, 'used_memory': 5087.8125}]
# order parameter
# tensor(0.9780, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 22/5000 [00:10<39:44,  2.09it/s]
# total loss
# tensor(80.4058, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.1875, 'used_memory': 5089.8125}]
# order parameter
# tensor(0.9780, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 23/5000 [00:11<39:29,  2.10it/s]
# total loss
# tensor(80.5851, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19476.1875, 'used_memory': 5087.8125}]
# order parameter
# tensor(0.9780, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 24/5000 [00:11<39:23,  2.11it/s]
# total loss
# tensor(80.5810, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19474.125, 'used_memory': 5089.875}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   0%|          | 25/5000 [00:12<39:46,  2.08it/s]
# total loss
# tensor(80.0752, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19486.125, 'used_memory': 5077.875}]
# model saved
# order parameter
# tensor(0.9778, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 26/5000 [00:12<39:50,  2.08it/s]
# total loss
# tensor(81.3130, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19478.8125, 'used_memory': 5085.1875}]
# model saved
# order parameter
# tensor(0.9781, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 27/5000 [00:13<40:34,  2.04it/s]
# total loss
# tensor(80.1572, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19462.8125, 'used_memory': 5101.1875}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 28/5000 [00:13<40:13,  2.06it/s]
# total loss
# tensor(80.0064, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.125, 'used_memory': 5098.875}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 29/5000 [00:14<40:10,  2.06it/s]
# total loss
# tensor(79.9400, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.125, 'used_memory': 5098.875}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 30/5000 [00:14<40:28,  2.05it/s]
# total loss
# tensor(79.8894, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.25, 'used_memory': 5098.75}]
# model saved
# order parameter
# tensor(0.9781, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 31/5000 [00:15<39:59,  2.07it/s]
# total loss
# tensor(80.2934, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.25, 'used_memory': 5098.75}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 32/5000 [00:15<39:55,  2.07it/s]
# total loss
# tensor(79.9139, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 33/5000 [00:16<40:20,  2.05it/s]
# total loss
# tensor(79.8244, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19467.375, 'used_memory': 5096.625}]
# model saved
# order parameter
# tensor(0.9782, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 34/5000 [00:16<40:43,  2.03it/s]
# total loss
# tensor(79.8538, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9783, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 35/5000 [00:16<40:33,  2.04it/s]
# total loss
# tensor(79.6340, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9785, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 36/5000 [00:17<40:46,  2.03it/s]
# total loss
# tensor(78.9286, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9786, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 37/5000 [00:17<40:55,  2.02it/s]
# total loss
# tensor(78.7308, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9786, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 38/5000 [00:18<40:45,  2.03it/s]
# total loss
# tensor(78.4999, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9786, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 39/5000 [00:18<40:30,  2.04it/s]
# total loss
# tensor(78.6770, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19467.375, 'used_memory': 5096.625}]
# model saved
# order parameter
# tensor(0.9788, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 40/5000 [00:19<40:28,  2.04it/s]
# total loss
# tensor(77.8163, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19467.375, 'used_memory': 5096.625}]
# model saved
# order parameter
# tensor(0.9787, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 41/5000 [00:19<40:25,  2.04it/s]
# total loss
# tensor(78.1850, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9787, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 42/5000 [00:20<40:30,  2.04it/s]
# total loss
# tensor(78.2172, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9789, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 43/5000 [00:20<40:44,  2.03it/s]
# total loss
# tensor(77.5171, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9789, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 44/5000 [00:21<40:31,  2.04it/s]
# total loss
# tensor(77.6088, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9793, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 45/5000 [00:21<40:29,  2.04it/s]
# total loss
# tensor(76.1380, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9789, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 46/5000 [00:22<40:32,  2.04it/s]
# total loss
# tensor(77.5974, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9794, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 47/5000 [00:22<40:14,  2.05it/s]
# total loss
# tensor(75.9406, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9794, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 48/5000 [00:23<40:01,  2.06it/s]
# total loss
# tensor(75.9203, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9791, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 49/5000 [00:23<40:29,  2.04it/s]
# total loss
# tensor(76.9570, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9791, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 50/5000 [00:24<40:09,  2.05it/s]
# total loss
# tensor(76.8267, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19467.375, 'used_memory': 5096.625}]
# model saved
# order parameter
# tensor(0.9795, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 51/5000 [00:24<40:08,  2.05it/s]
# total loss
# tensor(75.7569, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9797, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 52/5000 [00:25<40:33,  2.03it/s]
# total loss
# tensor(75.0709, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19467.375, 'used_memory': 5096.625}]
# model saved
# order parameter
# tensor(0.9796, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 53/5000 [00:25<40:13,  2.05it/s]
# total loss
# tensor(75.2317, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9800, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 54/5000 [00:26<40:29,  2.04it/s]
# total loss
# tensor(74.1131, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9798, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 55/5000 [00:26<40:18,  2.04it/s]
# total loss
# tensor(74.6302, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19465.375, 'used_memory': 5098.625}]
# model saved
# order parameter
# tensor(0.9801, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 56/5000 [00:27<40:41,  2.02it/s]
# total loss
# tensor(73.5397, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9798, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 57/5000 [00:27<40:21,  2.04it/s]
# total loss
# tensor(74.6833, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9801, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 58/5000 [00:28<40:19,  2.04it/s]
# total loss
# tensor(73.7971, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9805, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 59/5000 [00:28<40:40,  2.02it/s]
# total loss
# tensor(72.4716, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9804, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 60/5000 [00:29<40:19,  2.04it/s]
# total loss
# tensor(72.7007, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19512.375, 'used_memory': 5051.625}]
# model saved
# order parameter
# tensor(0.9807, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 61/5000 [00:29<40:21,  2.04it/s]
# total loss
# tensor(71.6377, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19512.125, 'used_memory': 5051.875}]
# model saved
# order parameter
# tensor(0.9809, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|          | 62/5000 [00:30<40:38,  2.02it/s]
# total loss
# tensor(71.1495, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.125, 'used_memory': 5053.875}]
# model saved
# order parameter
# tensor(0.9806, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 63/5000 [00:30<40:24,  2.04it/s]
# total loss
# tensor(72.0379, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.4375, 'used_memory': 5053.5625}]
# model saved
# order parameter
# tensor(0.9809, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 64/5000 [00:31<40:26,  2.03it/s]
# total loss
# tensor(70.8680, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.4375, 'used_memory': 5053.5625}]
# model saved
# order parameter
# tensor(0.9806, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 65/5000 [00:31<40:43,  2.02it/s]
# total loss
# tensor(71.8822, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19512.75, 'used_memory': 5051.25}]
# model saved
# order parameter
# tensor(0.9810, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 66/5000 [00:32<40:24,  2.03it/s]
# total loss
# tensor(70.5704, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9811, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 67/5000 [00:32<40:24,  2.03it/s]
# total loss
# tensor(70.3603, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9812, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 68/5000 [00:33<40:41,  2.02it/s]
# total loss
# tensor(69.9365, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9814, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 69/5000 [00:33<40:29,  2.03it/s]
# total loss
# tensor(69.3619, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9817, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 70/5000 [00:34<40:37,  2.02it/s]
# total loss
# tensor(68.0972, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9816, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 71/5000 [00:34<40:15,  2.04it/s]
# total loss
# tensor(68.7070, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9820, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 72/5000 [00:35<40:17,  2.04it/s]
# total loss
# tensor(67.3568, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9820, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 73/5000 [00:35<40:21,  2.04it/s]
# total loss
# tensor(67.0846, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19512.75, 'used_memory': 5051.25}]
# model saved
# order parameter
# tensor(0.9823, device='cuda:0', grad_fn=<MeanBackward0>)
#   1%|▏         | 74/5000 [00:36<40:04,  2.05it/s]
# total loss
# tensor(66.1850, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9822, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 75/5000 [00:36<40:34,  2.02it/s]
# total loss
# tensor(66.4758, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9823, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 76/5000 [00:37<40:20,  2.03it/s]
# total loss
# tensor(66.1209, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19512.75, 'used_memory': 5051.25}]
# model saved
# order parameter
# tensor(0.9827, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 77/5000 [00:37<40:14,  2.04it/s]
# total loss
# tensor(64.9609, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9828, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 78/5000 [00:38<39:56,  2.05it/s]
# total loss
# tensor(64.3802, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9828, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 79/5000 [00:38<40:02,  2.05it/s]
# total loss
# tensor(64.4463, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9832, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 80/5000 [00:39<40:24,  2.03it/s]
# total loss
# tensor(63.1712, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9833, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 81/5000 [00:39<40:08,  2.04it/s]
# total loss
# tensor(62.9438, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9832, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 82/5000 [00:40<39:55,  2.05it/s]
# total loss
# tensor(63.1063, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19510.75, 'used_memory': 5053.25}]
# model saved
# order parameter
# tensor(0.9836, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 83/5000 [00:40<40:24,  2.03it/s]
# total loss
# tensor(61.8204, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9835, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 84/5000 [00:41<40:31,  2.02it/s]
# total loss
# tensor(61.9655, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9840, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 85/5000 [00:41<40:24,  2.03it/s]
# total loss
# tensor(60.3558, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9840, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 86/5000 [00:42<40:05,  2.04it/s]
# total loss
# tensor(60.4755, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9842, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 87/5000 [00:42<40:13,  2.04it/s]
# total loss
# tensor(59.8269, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9844, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 88/5000 [00:43<39:49,  2.06it/s]
# total loss
# tensor(58.9937, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9845, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 89/5000 [00:43<39:43,  2.06it/s]
# total loss
# tensor(58.6623, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9848, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 90/5000 [00:43<39:38,  2.06it/s]
# total loss
# tensor(57.4931, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9851, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 91/5000 [00:44<39:38,  2.06it/s]
# total loss
# tensor(56.6686, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9850, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 92/5000 [00:44<39:43,  2.06it/s]
# total loss
# tensor(57.0234, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9851, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 93/5000 [00:45<40:02,  2.04it/s]
# total loss
# tensor(56.4389, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9854, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 94/5000 [00:45<40:11,  2.03it/s]
# total loss
# tensor(55.5314, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9857, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 95/5000 [00:46<39:56,  2.05it/s]
# total loss
# tensor(54.5271, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9856, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 96/5000 [00:46<40:00,  2.04it/s]
# total loss
# tensor(54.8429, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9858, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 97/5000 [00:47<40:24,  2.02it/s]
# total loss
# tensor(53.9644, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9863, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 98/5000 [00:47<40:39,  2.01it/s]
# total loss
# tensor(52.2356, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9864, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 99/5000 [00:48<40:01,  2.04it/s]
# total loss
# tensor(52.0228, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9864, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 100/5000 [00:48<40:18,  2.03it/s]
# total loss
# tensor(52.0913, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9866, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 101/5000 [00:49<40:23,  2.02it/s]
# total loss
# tensor(51.0875, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9869, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 102/5000 [00:49<39:54,  2.05it/s]
# total loss
# tensor(50.2145, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9870, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 103/5000 [00:50<39:50,  2.05it/s]
# total loss
# tensor(49.8493, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9871, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 104/5000 [00:50<39:53,  2.05it/s]
# total loss
# tensor(49.4924, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9874, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 105/5000 [00:51<39:38,  2.06it/s]
# total loss
# tensor(48.2470, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9874, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 106/5000 [00:51<39:29,  2.07it/s]
# total loss
# tensor(48.4641, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9876, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 107/5000 [00:52<39:50,  2.05it/s]
# total loss
# tensor(47.7312, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9879, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 108/5000 [00:52<39:47,  2.05it/s]
# total loss
# tensor(46.7403, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9881, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 109/5000 [00:53<39:33,  2.06it/s]
# total loss
# tensor(45.9701, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9882, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 110/5000 [00:53<39:50,  2.05it/s]
# total loss
# tensor(45.4913, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9882, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 111/5000 [00:54<40:18,  2.02it/s]
# total loss
# tensor(45.4578, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9885, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 112/5000 [00:54<40:15,  2.02it/s]
# total loss
# tensor(44.5395, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9888, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 113/5000 [00:55<39:58,  2.04it/s]
# total loss
# tensor(43.3768, device='cuda:0', grad_fn=<MeanBackward0>)
# [{'device': 0, 'total_memory': 24564.0, 'free_memory': 19514.75, 'used_memory': 5049.25}]
# model saved
# order parameter
# tensor(0.9889, device='cuda:0', grad_fn=<MeanBackward0>)
#   2%|▏         | 113/5000 [00:55<40:04,  2.03it/s]
#
# KeyboardInterrupt

# %%
gc.collect()
torch.cuda.empty_cache()            
global_stats=[]
global_means=[]
global_stds=[]
global_pnumel=[]

dist = torch.distributions.Normal(0, 1)
for layers in range(0,5):
    learning_rate=0.0001
    diff=0.0
    gamma=0.999
  
    skip=False
    strategy="tHOL_Pareto"
    diff=0
    SML= KuramotoHyperUniversal(batch_size, state_size, Kcrit, freqs,A, layers,diff,skip,strategy,device).to(device)
    load_clean_state_dict(SML,  path+"/SML_Kur_v3" + str(layers)+ ".pth")
    total_params = sum(p.numel() for p in SML.poly.hhnet.parameters())
    global_pnumel.append(total_params)
    alpha=0.995
    params=find_params(SML)
    controller_optimizer = torch.optim.AdamW(params, lr=learning_rate,  weight_decay=0.0, amsgrad=False)
    #controller_optimizer = AdaBelief(params, lr=learning_rate, eps=1e-16, betas=(0.9,0.999), weight_decouple = True, rectify = True, amsgrad=False)
    ema_model = torch.optim.swa_utils.AveragedModel(SML, multi_avg_fn=torch.optim.swa_utils.get_ema_multi_avg_fn(alpha)).to(device)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(controller_optimizer, gamma=gamma)
    
    
  
    t_size=32
    iter = 100
    t_total=1
    
    t = np.linspace(0, iter, iter)

    ts_exp = torch.linspace(0, t_total, t_size).to(device)
    
    perf=[]
    eperf=[]
    stperf=[]
    erpe=[]
    strf=[]
    orpam=[]
    st_orpam=[]
    

    ema_loss=0
    ema_ener=0
    score=1000000
    
    t = np.linspace(0, iter, iter) 
    
    antithetic=True
    orparam=0
    
    count=0
    mean=0
    M2=0
    for j in tqdm(range(iter)):
        x0_raw = torch.randn(int(batch_size/2), state_size, device=device) 
        x0_raw = torch.cat([x0_raw,-x0_raw],dim=0)
        ys_exp = torch.cat((x0_raw/scale_kin,torch.zeros(batch_size, 1).to(device)),dim=1).to(device)
 
        if antithetic:
            #samples = torch.distributions.Beta(2, 2).sample((int(batch_size/2),state_size)).to(device) -.5
            #anti_samples =  - samples
    
            #freqs = torch.cat([samples, anti_samples], dim=0)

            
            

            # 1. Map bounds to CDF range
            low_cdf = dist.cdf(torch.tensor(-3).to(device))
            high_cdf = dist.cdf(torch.tensor(3).to(device))
            
            # 2. Sample Uniformly in CDF space and transform back (ICDF)
            u = torch.rand(int(batch_size/2), state_size, device=device)
            freq1 = dist.icdf(low_cdf + u * (high_cdf - low_cdf))
            
            # 3. Concatenate antithetic pairs
            freqs = torch.cat((freq1, -freq1), dim=0)/scale

            
            
        else:
            freq=torch.randn(int(batch_size),state_size).to(device)/scale
           
  
        #rmat = torch.sort(rmat, dim=0).values
       
        SML.freqs=freqs
        exprmat=torch.pow(10**(1/2),(lb + (rmat + 0.5) * (ub - lb)))
        
        ys_tray = torchsde.sdeint_adjoint(SML, ys_exp, ts_exp,method='reversible_heun', dt=ts_exp[1]-ts_exp[0],
                                     adjoint_method='adjoint_reversible_heun',)
    
        
        obj= objective(ys_tray[-1,:,0:state_size],A)
        dif= exprmat.squeeze(1)*ys_tray[-1,:,-1]
      
        lossvec=obj+dif
        loss=torch.mean(lossvec)

             
        
        batch=lossvec.detach().cpu().numpy()
        b_count=batch.size
        b_mean=batch.mean()
        b_M2 = ((batch - b_mean) ** 2).sum()
        delta = b_mean - mean
        total = count + b_count    
        mean += delta * b_count / total
        M2 += b_M2 + delta**2 * count * b_count / total    
        count = total
       
        print("current ste")
        print(np.sqrt(M2/(total-1))/np.sqrt(total))
        print("current mean")
        print(mean)
        gc.collect()
        torch.cuda.empty_cache()
        if j>100 and j%500==0:
                clear_output(wait=False)
      
        del ys_tray, lossvec, loss, obj, dif
        
    variance = M2/ (count-1)
    ste= np.sqrt(variance)/np.sqrt(count)
   
    global_means.append(mean)
    global_stds.append(ste)

    
    with torch.no_grad():
        torch.cuda.empty_cache()
    gc.collect()
# Out:
#   1%|          | 1/100 [00:00<00:20,  4.79it/s]
# current ste
# 0.009599490002311133
# current mean
# 3.4235053062438965
# current ste
# 0.006513792366438397
# current mean
# 3.417613983154297
#   3%|▎         | 3/100 [00:00<00:20,  4.69it/s]
# current ste
# 0.005259404222648724
# current mean
# 3.4155468940734863
# current ste
# 0.004574742334248308
# current mean
# 3.4157875180244446
#   5%|▌         | 5/100 [00:01<00:20,  4.69it/s]
# current ste
# 0.004113527310607535
# current mean
# 3.4144373893737794
# current ste
# 0.003765064878617549
# current mean
# 3.417158921559652
#   7%|▋         | 7/100 [00:01<00:19,  4.72it/s]
# current ste
# 0.0035176136761475687
# current mean
# 3.418128320149013
# current ste
# 0.0033099301381578614
# current mean
# 3.421026438474655
#   9%|▉         | 9/100 [00:01<00:18,  4.84it/s]
# current ste
# 0.0031037619913862097
# current mean
# 3.4188492563035755
# current ste
# 0.0029402464858170577
# current mean
# 3.4192607879638675
#  11%|█         | 11/100 [00:02<00:18,  4.84it/s]
# current ste
# 0.002801295889773565
# current mean
# 3.420270312916149
# current ste
# 0.0026877581318133117
# current mean
# 3.420682748158773
#  13%|█▎        | 13/100 [00:02<00:18,  4.82it/s]
# current ste
# 0.002577410091375741
# current mean
# 3.4198792714339037
# current ste
# 0.002484749612733571
# current mean
# 3.4194237674985613
#  15%|█▌        | 15/100 [00:03<00:18,  4.71it/s]
# current ste
# 0.002401512984194976
# current mean
# 3.4193962891896565
# current ste
# 0.0023243017590526952
# current mean
# 3.418015167117119
#  17%|█▋        | 17/100 [00:03<00:17,  4.71it/s]
# current ste
# 0.002260594862478294
# current mean
# 3.4187490940093994
# current ste
# 0.0021932225440326678
# current mean
# 3.418334126472473
#  19%|█▉        | 19/100 [00:03<00:17,  4.75it/s]
# current ste
# 0.0021364591131334443
# current mean
# 3.41737531360827
# current ste
# 0.002081353944318201
# current mean
# 3.4157561182975766
#  21%|██        | 21/100 [00:04<00:16,  4.71it/s]
# current ste
# 0.002030001761666444
# current mean
# 3.4159406707400364
# current ste
# 0.0019849180256651475
# current mean
# 3.415607842532071
#  23%|██▎       | 23/100 [00:04<00:16,  4.66it/s]
# current ste
# 0.0019435059264663638
# current mean
# 3.4163988776828926
# current ste
# 0.0019037213494775716
# current mean
# 3.4171184698740635
#  25%|██▌       | 25/100 [00:05<00:15,  4.69it/s]
# current ste
# 0.0018659607798218731
# current mean
# 3.4167929649353024
# current ste
# 0.0018259171005751413
# current mean
# 3.4151725769042964
#  27%|██▋       | 27/100 [00:05<00:15,  4.70it/s]
# current ste
# 0.0017937738701712669
# current mean
# 3.4162378840976286
# current ste
# 0.001760390876370922
# current mean
# 3.4160516432353423
#  29%|██▉       | 29/100 [00:06<00:14,  4.76it/s]
# current ste
# 0.0017311201302762848
# current mean
# 3.416758825039041
# current ste
# 0.0017040177337218634
# current mean
# 3.4164244731267286
#  31%|███       | 31/100 [00:06<00:14,  4.76it/s]
# current ste
# 0.001678655792918057
# current mean
# 3.416258527386572
# current ste
# 0.0016548168084163195
# current mean
# 3.4165126606822005
#  33%|███▎      | 33/100 [00:06<00:14,  4.76it/s]
# current ste
# 0.0016328259838357976
# current mean
# 3.41681103995352
# current ste
# 0.0016056909305559354
# current mean
# 3.415837189730475
#  35%|███▌      | 35/100 [00:07<00:13,  4.79it/s]
# current ste
# 0.0015825949645609035
# current mean
# 3.4163815498352044
# current ste
# 0.0015592100615970618
# current mean
# 3.416106892956627
#  37%|███▋      | 37/100 [00:07<00:13,  4.80it/s]
# current ste
# 0.0015380585077681328
# current mean
# 3.415930168048755
# current ste
# 0.0015194068739335814
# current mean
# 3.4158178567886344
#  39%|███▉      | 39/100 [00:08<00:12,  4.81it/s]
# current ste
# 0.001502081804916389
# current mean
# 3.4165733594160805
# current ste
# 0.0014832491500424293
# current mean
# 3.4161862611770624
#  41%|████      | 41/100 [00:08<00:12,  4.79it/s]
# current ste
# 0.0014642532469890713
# current mean
# 3.4157199627015644
# current ste
# 0.001446994754919739
# current mean
# 3.415569555191766
#  43%|████▎     | 43/100 [00:09<00:11,  4.83it/s]
# current ste
# 0.0014292233538069682
# current mean
# 3.415162202923796
# current ste
# 0.0014113788027655379
# current mean
# 3.415290957147424
#  45%|████▌     | 45/100 [00:09<00:11,  4.77it/s]
# current ste
# 0.0013954366714678647
# current mean
# 3.4154585202534986
# current ste
# 0.0013792491332436224
# current mean
# 3.4151064001995577
#  47%|████▋     | 47/100 [00:09<00:11,  4.76it/s]
# current ste
# 0.0013652011294487084
# current mean
# 3.41517571692771
# current ste
# 0.0013508496858721459
# current mean
# 3.415350769956906
#  49%|████▉     | 49/100 [00:10<00:10,  4.78it/s]
# current ste
# 0.00133705036044785
# current mean
# 3.415088512459579
# current ste
# 0.001324471064994005
# current mean
# 3.4149663400650017
#  51%|█████     | 51/100 [00:10<00:10,  4.88it/s]
# current ste
# 0.001310489487379194
# current mean
# 3.4150638066086105
# current ste
# 0.0012978791317859659
# current mean
# 3.4146022567382217
#  53%|█████▎    | 53/100 [00:11<00:09,  4.87it/s]
# current ste
# 0.0012848538890583322
# current mean
# 3.414371674915529
# current ste
# 0.0012729688371280819
# current mean
# 3.4145259636419785
#  55%|█████▌    | 55/100 [00:11<00:09,  4.61it/s]
# current ste
# 0.0012620831098915243
# current mean
# 3.4146832682869643
# current ste
# 0.0012502396364748349
# current mean
# 3.4147023175443914
#  57%|█████▋    | 57/100 [00:12<00:09,  4.53it/s]
# current ste
# 0.0012387055278017982
# current mean
# 3.4144505408772243
# current ste
# 0.0012285869981807143
# current mean
# 3.4141705323909886
#  59%|█████▉    | 59/100 [00:12<00:08,  4.57it/s]
# current ste
# 0.0012179013513132304
# current mean
# 3.414188211247072
# current ste
# 0.0012081745360611003
# current mean
# 3.4144020199775693
#  61%|██████    | 61/100 [00:12<00:08,  4.70it/s]
# current ste
# 0.001198315944709452
# current mean
# 3.414811943398147
# current ste
# 0.0011880416409105216
# current mean
# 3.4147717568182174
#  63%|██████▎   | 63/100 [00:13<00:07,  4.72it/s]
# current ste
# 0.0011787848759421274
# current mean
# 3.4148054993341836
# current ste
# 0.0011688795924843299
# current mean
# 3.4155218787491317
#  65%|██████▌   | 65/100 [00:13<00:07,  4.66it/s]
# current ste
# 0.0011600957284851935
# current mean
# 3.4151947388282187
# current ste
# 0.0011516474077456905
# current mean
# 3.4152090621717046
#  67%|██████▋   | 67/100 [00:14<00:07,  4.56it/s]
# current ste
# 0.0011428896914820678
# current mean
# 3.4148556189750554
# current ste
# 0.001134306051431153
# current mean
# 3.414700238143696
#  69%|██████▉   | 69/100 [00:14<00:06,  4.74it/s]
# current ste
# 0.0011257552437360877
# current mean
# 3.414651428443798
# current ste
# 0.0011177206223443937
# current mean
# 3.4145994526999335
#  71%|███████   | 71/100 [00:14<00:05,  4.94it/s]
# current ste
# 0.0011085037092798786
# current mean
# 3.4147789343981674
# current ste
# 0.0011011567422597674
# current mean
# 3.414688769314024
#  73%|███████▎  | 73/100 [00:15<00:05,  4.90it/s]
# current ste
# 0.0010938678849525363
# current mean
# 3.414913807829765
# current ste
# 0.00108592859928862
# current mean
# 3.414995080715901
#  75%|███████▌  | 75/100 [00:15<00:05,  4.90it/s]
# current ste
# 0.0010785833027871972
# current mean
# 3.4150907770792642
# current ste
# 0.0010719222832772223
# current mean
# 3.415170741708655
#  77%|███████▋  | 77/100 [00:16<00:04,  4.90it/s]
# current ste
# 0.0010643102804733968
# current mean
# 3.4153119155338834
# current ste
# 0.0010570323295032102
# current mean
# 3.4150201326761493
#  79%|███████▉  | 79/100 [00:16<00:04,  4.73it/s]
# current ste
# 0.001050510365399402
# current mean
# 3.4149183472500573
# current ste
# 0.0010443894791876281
# current mean
# 3.4152054637670517
#  81%|████████  | 81/100 [00:17<00:04,  4.71it/s]
# current ste
# 0.0010384962323691177
# current mean
# 3.414977471033732
# current ste
# 0.0010326214690035296
# current mean
# 3.4151656656730465
#  83%|████████▎ | 83/100 [00:17<00:03,  4.57it/s]
# current ste
# 0.0010262315903233374
# current mean
# 3.415086599717657
# current ste
# 0.001020738223430505
# current mean
# 3.414783770129794
#  85%|████████▌ | 85/100 [00:17<00:03,  4.84it/s]
# current ste
# 0.0010146951307116803
# current mean
# 3.4149289355558508
# current ste
# 0.0010079607352254584
# current mean
# 3.414793768594431
#  87%|████████▋ | 87/100 [00:18<00:02,  4.86it/s]
# current ste
# 0.001002013852013194
# current mean
# 3.4147763416684906
# current ste
# 0.0009967086127721497
# current mean
# 3.4149992032484575
#  89%|████████▉ | 89/100 [00:18<00:02,  4.72it/s]
# current ste
# 0.000990814966470107
# current mean
# 3.4150847370704907
# current ste
# 0.0009851800458495139
# current mean
# 3.415368355645074
#  91%|█████████ | 91/100 [00:19<00:01,  4.57it/s]
# current ste
# 0.0009792972340567463
# current mean
# 3.4153368027655633
# current ste
# 0.0009738192522483174
# current mean
# 3.4155472724334053
#  93%|█████████▎| 93/100 [00:19<00:01,  4.62it/s]
# current ste
# 0.0009684704515895716
# current mean
# 3.415718347795548
# current ste
# 0.0009634232090765955
# current mean
# 3.415768209924089
#  95%|█████████▌| 95/100 [00:20<00:01,  4.69it/s]
# current ste
# 0.0009584150712144259
# current mean
# 3.4159625680823074
# current ste
# 0.0009529749408793263
# current mean
# 3.416022789975007
#  97%|█████████▋| 97/100 [00:20<00:00,  4.63it/s]
# current ste
# 0.0009476404726473238
# current mean
# 3.415950472821894
# current ste
# 0.0009427972069423334
# current mean
# 3.415732571056911
#  99%|█████████▉| 99/100 [00:20<00:00,  4.64it/s]
# current ste
# 0.0009382550932893503
# current mean
# 3.4161361805116286
# current ste
# 0.0009336793361760951
# current mean
# 3.415841870307922
# 100%|██████████| 100/100 [00:21<00:00,  4.73it/s]
#   1%|          | 1/100 [00:00<00:20,  4.79it/s]
# current ste
# 0.00791188709524202
# current mean
# 3.182079553604126
# current ste
# 0.005616077292229488
# current mean
# 3.178248882293701
#   3%|▎         | 3/100 [00:00<00:20,  4.82it/s]
# current ste
# 0.004588505752309531
# current mean
# 3.1799230575561523
# current ste
# 0.003988008043501423
# current mean
# 3.180773138999939
#   5%|▌         | 5/100 [00:01<00:19,  4.80it/s]
# current ste
# 0.0036061096337685577
# current mean
# 3.184582805633545
# current ste
# 0.0032610789549054743
# current mean
# 3.1813673973083496
#   7%|▋         | 7/100 [00:01<00:19,  4.74it/s]
# current ste
# 0.00301092753290107
# current mean
# 3.179341588701521
# current ste
# 0.002818806511714573
# current mean
# 3.179084300994873
#   9%|▉         | 9/100 [00:01<00:19,  4.75it/s]
# current ste
# 0.0026580067180370453
# current mean
# 3.1776733928256564
# current ste
# 0.002510292791827456
# current mean
# 3.1770910739898683
#  11%|█         | 11/100 [00:02<00:18,  4.73it/s]
# current ste
# 0.0023948759177369046
# current mean
# 3.1764272993261167
# current ste
# 0.002284256697379184
# current mean
# 3.1766131321589155
#  13%|█▎        | 13/100 [00:02<00:18,  4.79it/s]
# current ste
# 0.002191230257912277
# current mean
# 3.1757854681748614
# current ste
# 0.002116183752859721
# current mean
# 3.176339251654489
#  15%|█▌        | 15/100 [00:03<00:17,  4.78it/s]
# current ste
# 0.0020505745984486998
# current mean
# 3.176987075805664
# current ste
# 0.001989660894368125
# current mean
# 3.1765951365232468
#  17%|█▋        | 17/100 [00:03<00:17,  4.75it/s]
# current ste
# 0.001923381214182113
# current mean
# 3.176789129481596
# current ste
# 0.0018735406121630765
# current mean
# 3.1762340466181436
#  19%|█▉        | 19/100 [00:03<00:17,  4.73it/s]
# current ste
# 0.0018240990256383255
# current mean
# 3.1757034126080965
# current ste
# 0.0017789390726198982
# current mean
# 3.1758036017417908
#  21%|██        | 21/100 [00:04<00:16,  4.77it/s]
# current ste
# 0.0017336550004316315
# current mean
# 3.175822519120716
# current ste
# 0.0016900082058597197
# current mean
# 3.175487605008212
#  23%|██▎       | 23/100 [00:04<00:16,  4.74it/s]
# current ste
# 0.001654973298932337
# current mean
# 3.175462888634723
# current ste
# 0.0016214223057841768
# current mean
# 3.1749534209569297
#  25%|██▌       | 25/100 [00:05<00:15,  4.77it/s]
# current ste
# 0.0015902641675034253
# current mean
# 3.1748197269439697
# current ste
# 0.0015624504270311142
# current mean
# 3.1750233356769266
#  27%|██▋       | 27/100 [00:05<00:15,  4.74it/s]
# current ste
# 0.0015331970961615891
# current mean
# 3.1751226584116616
# current ste
# 0.0015041346841303455
# current mean
# 3.1751477548054283
#  29%|██▉       | 29/100 [00:06<00:14,  4.75it/s]
# current ste
# 0.0014791407663796385
# current mean
# 3.1744743051200075
# current ste
# 0.0014563769356693472
# current mean
# 3.174933266639709
#  31%|███       | 31/100 [00:06<00:14,  4.79it/s]
# current ste
# 0.001434173244623619
# current mean
# 3.174500565375051
# current ste
# 0.001412733175879493
# current mean
# 3.174513809382915
#  33%|███▎      | 33/100 [00:06<00:14,  4.69it/s]
# current ste
# 0.0013915444534416275
# current mean
# 3.17422291726777
# current ste
# 0.0013717387525509328
# current mean
# 3.1746867123772113
#  35%|███▌      | 35/100 [00:07<00:13,  4.69it/s]
# current ste
# 0.0013516422292659202
# current mean
# 3.1747862747737337
# current ste
# 0.0013346311497980396
# current mean
# 3.1748661465115013
#  37%|███▋      | 37/100 [00:07<00:13,  4.70it/s]
# current ste
# 0.0013159626539742185
# current mean
# 3.1748684096980737
# current ste
# 0.001298497679551695
# current mean
# 3.174689688180622
#  39%|███▉      | 39/100 [00:08<00:13,  4.63it/s]
# current ste
# 0.0012804986053550156
# current mean
# 3.174295859459119
# current ste
# 0.001264871288763931
# current mean
# 3.1739644348621368
#  41%|████      | 41/100 [00:08<00:12,  4.68it/s]
# current ste
# 0.0012491496266290095
# current mean
# 3.174113796978462
# current ste
# 0.0012346078192984743
# current mean
# 3.174106700079782
#  43%|████▎     | 43/100 [00:09<00:12,  4.71it/s]
# current ste
# 0.0012193029752991947
# current mean
# 3.174124168795209
# current ste
# 0.0012052887185031577
# current mean
# 3.174306289716201
#  45%|████▌     | 45/100 [00:09<00:11,  4.71it/s]
# current ste
# 0.0011916744852765787
# current mean
# 3.1742492198944094
# current ste
# 0.0011781102811419817
# current mean
# 3.1743640795997954
#  47%|████▋     | 47/100 [00:09<00:11,  4.73it/s]
# current ste
# 0.0011647779032805715
# current mean
# 3.1743219406046768
# current ste
# 0.0011532406827460576
# current mean
# 3.1740076641241712
#  49%|████▉     | 49/100 [00:10<00:10,  4.70it/s]
# current ste
# 0.0011413689932270028
# current mean
# 3.173732387776278
# current ste
# 0.001128884843056678
# current mean
# 3.1736166906356815
#  51%|█████     | 51/100 [00:10<00:10,  4.85it/s]
# current ste
# 0.0011169199831555319
# current mean
# 3.173560446383907
# current ste
# 0.001106850626429134
# current mean
# 3.1737584838500394
#  53%|█████▎    | 53/100 [00:11<00:09,  4.80it/s]
# current ste
# 0.0010956942169283459
# current mean
# 3.173669959014317
# current ste
# 0.0010847450299331244
# current mean
# 3.1737820572323274
#  55%|█████▌    | 55/100 [00:11<00:09,  4.76it/s]
# current ste
# 0.001076048835362934
# current mean
# 3.1741412596269094
# current ste
# 0.0010662297740018569
# current mean
# 3.174234432833536
#  57%|█████▋    | 57/100 [00:12<00:09,  4.77it/s]
# current ste
# 0.0010568916232960082
# current mean
# 3.174255755909703
# current ste
# 0.0010480273642097624
# current mean
# 3.17398449470257
#  59%|█████▉    | 59/100 [00:12<00:08,  4.82it/s]
# current ste
# 0.0010384752717796618
# current mean
# 3.1738969309855323
# current ste
# 0.0010300428736378941
# current mean
# 3.1738081296285
#  61%|██████    | 61/100 [00:12<00:08,  4.77it/s]
# current ste
# 0.0010219844921241531
# current mean
# 3.1743509026824457
# current ste
# 0.0010131295220150239
# current mean
# 3.1743221436777427
#  63%|██████▎   | 63/100 [00:13<00:07,  4.73it/s]
# current ste
# 0.0010047283830217307
# current mean
# 3.1742824675544865
# current ste
# 0.0009974533714546758
# current mean
# 3.174213416874409
#  65%|██████▌   | 65/100 [00:13<00:07,  4.79it/s]
# current ste
# 0.000988927702557619
# current mean
# 3.174053001403809
# current ste
# 0.0009813215045074508
# current mean
# 3.1740638956879126
#  67%|██████▋   | 67/100 [00:14<00:06,  4.78it/s]
# current ste
# 0.0009735441159024881
# current mean
# 3.1741057972409834
# current ste
# 0.0009669338402880005
# current mean
# 3.174354374408722
#  69%|██████▉   | 69/100 [00:14<00:06,  4.72it/s]
# current ste
# 0.0009600856433596778
# current mean
# 3.1743320969567783
# current ste
# 0.0009529364963362559
# current mean
# 3.174226907321385
#  71%|███████   | 71/100 [00:14<00:06,  4.73it/s]
# current ste
# 0.0009455845515433716
# current mean
# 3.174074062159364
# current ste
# 0.0009395175525157897
# current mean
# 3.174319860008028
#  73%|███████▎  | 73/100 [00:15<00:05,  4.71it/s]
# current ste
# 0.0009322685188281614
# current mean
# 3.174291052230417
# current ste
# 0.0009265339973100477
# current mean
# 3.1745006748147913
#  75%|███████▌  | 75/100 [00:15<00:05,  4.70it/s]
# current ste
# 0.000920313885672052
# current mean
# 3.174440730412801
# current ste
# 0.0009143168440758935
# current mean
# 3.1746451729222347
#  77%|███████▋  | 77/100 [00:16<00:04,  4.69it/s]
# current ste
# 0.0009087386010207855
# current mean
# 3.1744988800643323
# current ste
# 0.0009034142653633811
# current mean
# 3.1742356190314656
#  79%|███████▉  | 79/100 [00:16<00:04,  4.71it/s]
# current ste
# 0.0008976529128725058
# current mean
# 3.1742297848568684
# current ste
# 0.0008918866580273061
# current mean
# 3.1744818568229674
#  81%|████████  | 81/100 [00:17<00:03,  4.79it/s]
# current ste
# 0.0008865742240451828
# current mean
# 3.1743706479484652
# current ste
# 0.0008809693217524487
# current mean
# 3.1744929464851936
#  83%|████████▎ | 83/100 [00:17<00:03,  4.69it/s]
# current ste
# 0.0008758648414591726
# current mean
# 3.1747655753629753
# current ste
# 0.0008709372555061358
# current mean
# 3.174613498506092
#  85%|████████▌ | 85/100 [00:17<00:03,  4.72it/s]
# current ste
# 0.0008660972875809197
# current mean
# 3.1743502981522504
# current ste
# 0.0008608095347351776
# current mean
# 3.1743658725605455
#  87%|████████▋ | 87/100 [00:18<00:02,  4.75it/s]
# current ste
# 0.0008556398764074447
# current mean
# 3.1742655655433394
# current ste
# 0.0008500365515349792
# current mean
# 3.174128424037587
#  89%|████████▉ | 89/100 [00:18<00:02,  4.77it/s]
# current ste
# 0.0008450433728044827
# current mean
# 3.1741165739766672
# current ste
# 0.0008408290014227681
# current mean
# 3.1741235733032234
#  91%|█████████ | 91/100 [00:19<00:01,  4.65it/s]
# current ste
# 0.0008362315214647939
# current mean
# 3.174210218282847
# current ste
# 0.0008311370212520858
# current mean
# 3.1741140096083935
#  93%|█████████▎| 93/100 [00:19<00:01,  4.71it/s]
# current ste
# 0.0008265853835482853
# current mean
# 3.1741820817352626
# current ste
# 0.0008222880981754639
# current mean
# 3.174339444079298
#  95%|█████████▌| 95/100 [00:20<00:01,  4.73it/s]
# current ste
# 0.0008177503260623222
# current mean
# 3.17442142837926
# current ste
# 0.0008132247126108287
# current mean
# 3.174244898060958
#  97%|█████████▋| 97/100 [00:20<00:00,  4.72it/s]
# current ste
# 0.0008087509935584351
# current mean
# 3.1742379149210826
# current ste
# 0.0008046905827632448
# current mean
# 3.1741189932336615
#  99%|█████████▉| 99/100 [00:20<00:00,  4.76it/s]
# current ste
# 0.0008003683216068456
# current mean
# 3.1740099926187537
# current ste
# 0.0007966172305539333
# current mean
# 3.1741576886177065
# 100%|██████████| 100/100 [00:21<00:00,  4.74it/s]
#   1%|          | 1/100 [00:00<00:21,  4.71it/s]
# current ste
# 0.008371743081973141
# current mean
# 3.1578800678253174
# current ste
# 0.00573503802903441
# current mean
# 3.157650113105774
#   3%|▎         | 3/100 [00:00<00:20,  4.76it/s]
# current ste
# 0.004639928574324259
# current mean
# 3.162454922993978
# current ste
# 0.004046223170818396
# current mean
# 3.16606467962265
#   5%|▌         | 5/100 [00:01<00:20,  4.72it/s]
# current ste
# 0.003610519306229744
# current mean
# 3.1652504444122314
# current ste
# 0.0032925811240700755
# current mean
# 3.1644764741261797
#   7%|▋         | 7/100 [00:01<00:20,  4.52it/s]
# current ste
# 0.0030602278885864297
# current mean
# 3.166443620409284
# current ste
# 0.002854750721217352
# current mean
# 3.1663458347320557
#   9%|▉         | 9/100 [00:01<00:20,  4.49it/s]
# current ste
# 0.0026858772896551915
# current mean
# 3.166896184285482
# current ste
# 0.002536921948491403
# current mean
# 3.1663856983184817
#  11%|█         | 11/100 [00:02<00:19,  4.55it/s]
# current ste
# 0.002415871727857308
# current mean
# 3.1661537777293813
# current ste
# 0.002305627481736729
# current mean
# 3.165660341580709
#  13%|█▎        | 13/100 [00:02<00:19,  4.51it/s]
# current ste
# 0.002214863289528974
# current mean
# 3.1643231465266304
# current ste
# 0.002137475969509824
# current mean
# 3.1650179965155467
#  15%|█▌        | 15/100 [00:03<00:18,  4.57it/s]
# current ste
# 0.002057046682519686
# current mean
# 3.164324394861857
# current ste
# 0.001991060953023374
# current mean
# 3.164387360215187
#  17%|█▋        | 17/100 [00:03<00:18,  4.55it/s]
# current ste
# 0.0019293943244019596
# current mean
# 3.163777225157794
# current ste
# 0.001878072642436894
# current mean
# 3.163747363620334
#  19%|█▉        | 19/100 [00:04<00:17,  4.67it/s]
# current ste
# 0.001822246596756638
# current mean
# 3.1634205391532495
# current ste
# 0.0017745637483883453
# current mean
# 3.1637565255165097
#  21%|██        | 21/100 [00:04<00:16,  4.70it/s]
# current ste
# 0.0017302203841086164
# current mean
# 3.1636892386845177
# current ste
# 0.0016912534121341974
# current mean
# 3.16371983831579
#  23%|██▎       | 23/100 [00:05<00:16,  4.65it/s]
# current ste
# 0.001656226217170869
# current mean
# 3.163432919460794
# current ste
# 0.0016186141071020648
# current mean
# 3.1626733044783273
#  25%|██▌       | 25/100 [00:05<00:16,  4.63it/s]
# current ste
# 0.0015865277043428893
# current mean
# 3.162199478149414
# current ste
# 0.0015574084005395468
# current mean
# 3.162120617352999
#  27%|██▋       | 27/100 [00:05<00:16,  4.53it/s]
# current ste
# 0.0015297584724949203
# current mean
# 3.16207461003904
# current ste
# 0.001503445373095105
# current mean
# 3.162196201937539
#  29%|██▉       | 29/100 [00:06<00:15,  4.66it/s]
# current ste
# 0.0014749701083483925
# current mean
# 3.161870454919749
# current ste
# 0.00144824846941468
# current mean
# 3.1618342558542882
#  31%|███       | 31/100 [00:06<00:14,  4.74it/s]
# current ste
# 0.0014249436744102862
# current mean
# 3.161930753338721
# current ste
# 0.001402687163389781
# current mean
# 3.1618421524763103
#  33%|███▎      | 33/100 [00:07<00:14,  4.78it/s]
# current ste
# 0.00138268304117979
# current mean
# 3.16249934832255
# current ste
# 0.001361796539865669
# current mean
# 3.1623658993664905
#  35%|███▌      | 35/100 [00:07<00:13,  4.93it/s]
# current ste
# 0.0013427344514054444
# current mean
# 3.1619897297450468
# current ste
# 0.001325252952276748
# current mean
# 3.1627354290750285
#  37%|███▋      | 37/100 [00:07<00:13,  4.84it/s]
# current ste
# 0.0013100109013480367
# current mean
# 3.1627869154955883
# current ste
# 0.0012924574651458033
# current mean
# 3.1630081565756543
#  39%|███▉      | 39/100 [00:08<00:12,  4.81it/s]
# current ste
# 0.001275319144112019
# current mean
# 3.1633206819876643
# current ste
# 0.0012601551000152515
# current mean
# 3.163763004541397
#  41%|████      | 41/100 [00:08<00:12,  4.89it/s]
# current ste
# 0.001243290840101405
# current mean
# 3.163945500443621
# current ste
# 0.0012267902227578982
# current mean
# 3.1641631921132403
#  43%|████▎     | 43/100 [00:09<00:11,  4.81it/s]
# current ste
# 0.0012118123288897195
# current mean
# 3.164158477339633
# current ste
# 0.0011974058013949223
# current mean
# 3.1640712564641773
#  45%|████▌     | 45/100 [00:09<00:11,  4.77it/s]
# current ste
# 0.0011836017593915488
# current mean
# 3.163872157202826
# current ste
# 0.0011693486146319282
# current mean
# 3.164114506348319
#  47%|████▋     | 47/100 [00:10<00:11,  4.73it/s]
# current ste
# 0.0011562377783307226
# current mean
# 3.1645341731132337
# current ste
# 0.0011441494155677288
# current mean
# 3.1643399596214286
#  49%|████▉     | 49/100 [00:10<00:10,  4.76it/s]
# current ste
# 0.0011325900929672371
# current mean
# 3.164527177810668
# current ste
# 0.0011211619091115608
# current mean
# 3.164195470809936
#  51%|█████     | 51/100 [00:10<00:10,  4.73it/s]
# current ste
# 0.0011102433495323678
# current mean
# 3.1641593820908485
# current ste
# 0.001099078245919863
# current mean
# 3.1641967984346238
#  53%|█████▎    | 53/100 [00:11<00:09,  4.71it/s]
# current ste
# 0.0010901453533603298
# current mean
# 3.1641230898083377
# current ste
# 0.0010808042285494408
# current mean
# 3.1639295904724682
#  55%|█████▌    | 55/100 [00:11<00:09,  4.76it/s]
# current ste
# 0.0010709190124551207
# current mean
# 3.1640249902551822
# current ste
# 0.0010609749532084357
# current mean
# 3.1641829013824463
#  57%|█████▋    | 57/100 [00:12<00:09,  4.75it/s]
# current ste
# 0.0010513772855025364
# current mean
# 3.1639703282138756
# current ste
# 0.0010420052701826331
# current mean
# 3.1640710296302004
#  59%|█████▉    | 59/100 [00:12<00:08,  4.78it/s]
# current ste
# 0.001032907319357956
# current mean
# 3.164173974829205
# current ste
# 0.001024002705728201
# current mean
# 3.164332501093546
#  61%|██████    | 61/100 [00:12<00:08,  4.77it/s]
# current ste
# 0.0010153562329808504
# current mean
# 3.1641306838051215
# current ste
# 0.0010069612724555811
# current mean
# 3.164259991338176
#  63%|██████▎   | 63/100 [00:13<00:07,  4.74it/s]
# current ste
# 0.000999563198794137
# current mean
# 3.1645040966215587
# current ste
# 0.0009912738836602732
# current mean
# 3.1644898131489754
#  65%|██████▌   | 65/100 [00:13<00:07,  4.78it/s]
# current ste
# 0.0009835941577197485
# current mean
# 3.1645294189453126
# current ste
# 0.0009769748277137274
# current mean
# 3.1644599148721406
#  67%|██████▋   | 67/100 [00:14<00:06,  4.76it/s]
# current ste
# 0.0009696548340589173
# current mean
# 3.1643215649163547
# current ste
# 0.0009625303988323396
# current mean
# 3.164413788739373
#  69%|██████▉   | 69/100 [00:14<00:06,  4.78it/s]
# current ste
# 0.0009546747178548602
# current mean
# 3.1642792293990873
# current ste
# 0.0009477960514069051
# current mean
# 3.1639834267752516
#  71%|███████   | 71/100 [00:15<00:06,  4.78it/s]
# current ste
# 0.0009404809719127141
# current mean
# 3.163687773153816
# current ste
# 0.000932846630496658
# current mean
# 3.163779781924354
#  73%|███████▎  | 73/100 [00:15<00:05,  4.75it/s]
# current ste
# 0.0009257557796589764
# current mean
# 3.1637127758705454
# current ste
# 0.000918979644931528
# current mean
# 3.1637119473637765
#  75%|███████▌  | 75/100 [00:15<00:05,  4.75it/s]
# current ste
# 0.0009129185588701671
# current mean
# 3.1636748981475833
# current ste
# 0.0009068334508790409
# current mean
# 3.163633286952973
#  77%|███████▋  | 77/100 [00:16<00:04,  4.75it/s]
# current ste
# 0.000900771406259789
# current mean
# 3.1636274232492823
# current ste
# 0.0008952469342982537
# current mean
# 3.1633865619317083
#  79%|███████▉  | 79/100 [00:16<00:04,  4.77it/s]
# current ste
# 0.0008900281707064737
# current mean
# 3.163382315937477
# current ste
# 0.0008846448087452839
# current mean
# 3.163471019268036
#  81%|████████  | 81/100 [00:17<00:03,  4.76it/s]
# current ste
# 0.0008789071187816055
# current mean
# 3.1636896251160422
# current ste
# 0.0008735270336664707
# current mean
# 3.1635907306903746
#  83%|████████▎ | 83/100 [00:17<00:03,  4.72it/s]
# current ste
# 0.0008674987082515873
# current mean
# 3.1633992396205306
# current ste
# 0.0008624299125024616
# current mean
# 3.1632806403296336
#  85%|████████▌ | 85/100 [00:18<00:03,  4.74it/s]
# current ste
# 0.0008569583776529625
# current mean
# 3.163459817100974
# current ste
# 0.0008523324767240005
# current mean
# 3.163573093192522
#  87%|████████▋ | 87/100 [00:18<00:02,  4.75it/s]
# current ste
# 0.0008474987716037143
# current mean
# 3.163492421994264
# current ste
# 0.0008428997731086931
# current mean
# 3.1635558930310337
#  89%|████████▉ | 89/100 [00:18<00:02,  4.75it/s]
# current ste
# 0.0008378983157448246
# current mean
# 3.1635783415162164
# current ste
# 0.0008331134957832424
# current mean
# 3.1635685020022923
#  91%|█████████ | 91/100 [00:19<00:01,  4.76it/s]
# current ste
# 0.0008285278979909452
# current mean
# 3.163485422239199
# current ste
# 0.0008242354273493564
# current mean
# 3.163396812003592
#  93%|█████████▎| 93/100 [00:19<00:01,  4.74it/s]
# current ste
# 0.0008194101979176949
# current mean
# 3.1634426886035554
# current ste
# 0.0008145422918277787
# current mean
# 3.163473233263544
#  95%|█████████▌| 95/100 [00:20<00:01,  4.79it/s]
# current ste
# 0.00081023695454005
# current mean
# 3.1634573810978943
# current ste
# 0.0008059815071925989
# current mean
# 3.163306089739005
#  97%|█████████▋| 97/100 [00:20<00:00,  4.91it/s]
# current ste
# 0.0008018931876600094
# current mean
# 3.1633367661348326
# current ste
# 0.0007977994746162539
# current mean
# 3.16343629360199
#  99%|█████████▉| 99/100 [00:20<00:00,  4.96it/s]
# current ste
# 0.0007938171260041003
# current mean
# 3.1634806936437436
# current ste
# 0.0007898061482456744
# current mean
# 3.1634080290794375
# 100%|██████████| 100/100 [00:21<00:00,  4.73it/s]
#   1%|          | 1/100 [00:00<00:24,  4.03it/s]
# current ste
# 0.00789864165622449
# current mean
# 3.156623363494873
# current ste
# 0.005555399374111807
# current mean
# 3.161380171775818
#   3%|▎         | 3/100 [00:00<00:20,  4.74it/s]
# current ste
# 0.004477350929140552
# current mean
# 3.158953825632731
# current ste
# 0.003912169448589349
# current mean
# 3.162284731864929
#   5%|▌         | 5/100 [00:01<00:20,  4.75it/s]
# current ste
# 0.003500289754483929
# current mean
# 3.1595396995544434
# current ste
# 0.0032012955511344096
# current mean
# 3.1603517532348633
#   7%|▋         | 7/100 [00:01<00:19,  4.73it/s]
# current ste
# 0.002951165529654986
# current mean
# 3.1604626859937395
# current ste
# 0.002782078081204899
# current mean
# 3.1623980700969696
#   9%|▉         | 9/100 [00:01<00:18,  4.79it/s]
# current ste
# 0.0026178612928475908
# current mean
# 3.1598417229122586
# current ste
# 0.0024915376448107307
# current mean
# 3.1588501214981077
#  11%|█         | 11/100 [00:02<00:18,  4.85it/s]
# current ste
# 0.002373899574062389
# current mean
# 3.1587303768504746
# current ste
# 0.0022727858205963325
# current mean
# 3.159210662047068
#  13%|█▎        | 13/100 [00:02<00:18,  4.79it/s]
# current ste
# 0.00218791910354946
# current mean
# 3.1598793726701
# current ste
# 0.002106919701384235
# current mean
# 3.160522597176688
#  15%|█▌        | 15/100 [00:03<00:17,  4.75it/s]
# current ste
# 0.002035877402353861
# current mean
# 3.15978954633077
# current ste
# 0.001978959249175285
# current mean
# 3.1606924533843994
#  17%|█▋        | 17/100 [00:03<00:17,  4.73it/s]
# current ste
# 0.0019240709839753987
# current mean
# 3.161339058595545
# current ste
# 0.0018691788546034646
# current mean
# 3.162135574552748
#  19%|█▉        | 19/100 [00:04<00:17,  4.68it/s]
# current ste
# 0.001816046104490894
# current mean
# 3.162365888294421
# current ste
# 0.001770485558569233
# current mean
# 3.161736524105072
#  21%|██        | 21/100 [00:04<00:16,  4.73it/s]
# current ste
# 0.0017306764296765342
# current mean
# 3.1622073423294794
# current ste
# 0.0016867708764819781
# current mean
# 3.1625319069082085
#  23%|██▎       | 23/100 [00:04<00:16,  4.75it/s]
# current ste
# 0.0016517902291635959
# current mean
# 3.163139249967492
# current ste
# 0.0016168269281170743
# current mean
# 3.1639404396216073
#  25%|██▌       | 25/100 [00:05<00:15,  4.73it/s]
# current ste
# 0.001586114748556549
# current mean
# 3.164347162246704
# current ste
# 0.0015555411506616222
# current mean
# 3.1641875688846293
#  27%|██▋       | 27/100 [00:05<00:15,  4.74it/s]
# current ste
# 0.0015252338540957036
# current mean
# 3.1638431107556375
# current ste
# 0.0014941980615082358
# current mean
# 3.163701781204768
#  29%|██▉       | 29/100 [00:06<00:14,  4.75it/s]
# current ste
# 0.0014663968882016184
# current mean
# 3.1632473468780513
# current ste
# 0.001442779825765802
# current mean
# 3.1632175922393793
#  31%|███       | 31/100 [00:06<00:14,  4.73it/s]
# current ste
# 0.001420045715132896
# current mean
# 3.1633802536995175
# current ste
# 0.0013960326836226942
# current mean
# 3.1629616916179653
#  33%|███▎      | 33/100 [00:06<00:14,  4.73it/s]
# current ste
# 0.0013774544553170076
# current mean
# 3.1624558694434883
# current ste
# 0.0013587668251692673
# current mean
# 3.1626400526832126
#  35%|███▌      | 35/100 [00:07<00:13,  4.72it/s]
# current ste
# 0.00133999591191983
# current mean
# 3.1624986989157535
# current ste
# 0.0013202976349026875
# current mean
# 3.1620892087618504
#  37%|███▋      | 37/100 [00:07<00:13,  4.70it/s]
# current ste
# 0.0013001513768318186
# current mean
# 3.1615943328754317
# current ste
# 0.0012826527318308876
# current mean
# 3.161750586409317
#  39%|███▉      | 39/100 [00:08<00:12,  4.75it/s]
# current ste
# 0.0012693367763806191
# current mean
# 3.1618696176088767
# current ste
# 0.0012533583751551032
# current mean
# 3.1621690452098843
#  41%|████      | 41/100 [00:08<00:12,  4.75it/s]
# current ste
# 0.0012365984428384027
# current mean
# 3.1616049510676683
# current ste
# 0.0012225442576529093
# current mean
# 3.162162451517014
#  43%|████▎     | 43/100 [00:09<00:11,  4.78it/s]
# current ste
# 0.0012088329944331974
# current mean
# 3.1624149389045177
# current ste
# 0.001193781089821069
# current mean
# 3.162372090599753
#  45%|████▌     | 45/100 [00:09<00:11,  4.76it/s]
# current ste
# 0.0011794735281826529
# current mean
# 3.1623071405622687
# current ste
# 0.0011670205325672507
# current mean
# 3.162399753280307
#  47%|████▋     | 47/100 [00:09<00:11,  4.75it/s]
# current ste
# 0.0011546115367708153
# current mean
# 3.1623167484364605
# current ste
# 0.0011438400515955652
# current mean
# 3.161982029676437
#  49%|████▉     | 49/100 [00:10<00:10,  4.78it/s]
# current ste
# 0.001131192248470155
# current mean
# 3.1622464267575006
# current ste
# 0.0011199402079299227
# current mean
# 3.1620486116409294
#  51%|█████     | 51/100 [00:10<00:10,  4.72it/s]
# current ste
# 0.0011084111677753957
# current mean
# 3.1620903716367827
# current ste
# 0.0010972378798723775
# current mean
# 3.161924696885622
#  53%|█████▎    | 53/100 [00:11<00:10,  4.68it/s]
# current ste
# 0.0010876559348634617
# current mean
# 3.161977871409002
# current ste
# 0.0010773867804806537
# current mean
# 3.1619954329949835
#  55%|█████▌    | 55/100 [00:11<00:09,  4.67it/s]
# current ste
# 0.0010684382171139172
# current mean
# 3.1619258577173404
# current ste
# 0.001059611610618837
# current mean
# 3.162201987845557
#  57%|█████▋    | 57/100 [00:12<00:09,  4.64it/s]
# current ste
# 0.001050236651983464
# current mean
# 3.162556309449045
# current ste
# 0.0010408953011029215
# current mean
# 3.1626480817794795
#  59%|█████▉    | 59/100 [00:12<00:08,  4.64it/s]
# current ste
# 0.0010318338918878598
# current mean
# 3.162412570694745
# current ste
# 0.0010235937684537433
# current mean
# 3.1622738877932224
#  61%|██████    | 61/100 [00:12<00:08,  4.71it/s]
# current ste
# 0.0010158819852881399
# current mean
# 3.1624824492657764
# current ste
# 0.0010080339518589705
# current mean
# 3.1627825498580924
#  63%|██████▎   | 63/100 [00:13<00:07,  4.70it/s]
# current ste
# 0.0009997909370726783
# current mean
# 3.1627045056176555
# current ste
# 0.0009911646931570735
# current mean
# 3.1625882387161246
#  65%|██████▌   | 65/100 [00:13<00:07,  4.69it/s]
# current ste
# 0.0009831971738883212
# current mean
# 3.162419135753924
# current ste
# 0.0009748765337345565
# current mean
# 3.1622773445013785
#  67%|██████▋   | 67/100 [00:14<00:07,  4.65it/s]
# current ste
# 0.0009680474718085778
# current mean
# 3.1623496084070903
# current ste
# 0.0009607884491999541
# current mean
# 3.162348463254815
#  69%|██████▉   | 69/100 [00:14<00:06,  4.74it/s]
# current ste
# 0.0009527977034303066
# current mean
# 3.1623401814612775
# current ste
# 0.0009459168745294147
# current mean
# 3.162299561500548
#  71%|███████   | 71/100 [00:15<00:06,  4.78it/s]
# current ste
# 0.0009393714671011703
# current mean
# 3.1622689005354747
# current ste
# 0.000932712222020591
# current mean
# 3.1624466776847826
#  73%|███████▎  | 73/100 [00:15<00:05,  4.71it/s]
# current ste
# 0.0009259603116314932
# current mean
# 3.1625422712874727
# current ste
# 0.000919649119859841
# current mean
# 3.1622643406326696
#  75%|███████▌  | 75/100 [00:15<00:05,  4.64it/s]
# current ste
# 0.0009132177028327725
# current mean
# 3.1622596867879222
# current ste
# 0.0009062930632855407
# current mean
# 3.1623462344470767
#  77%|███████▋  | 77/100 [00:16<00:04,  4.66it/s]
# current ste
# 0.0009005669776540847
# current mean
# 3.162257578465845
# current ste
# 0.000894669852006733
# current mean
# 3.1621991976713515
#  79%|███████▉  | 79/100 [00:16<00:04,  4.65it/s]
# current ste
# 0.000888432595250329
# current mean
# 3.1622282704220535
# current ste
# 0.0008829504709460421
# current mean
# 3.1622776806354516
#  81%|████████  | 81/100 [00:17<00:04,  4.67it/s]
# current ste
# 0.0008775465161141815
# current mean
# 3.1623612627571003
# current ste
# 0.0008726712278610775
# current mean
# 3.162312359344668
#  83%|████████▎ | 83/100 [00:17<00:03,  4.66it/s]
# current ste
# 0.0008672790953237518
# current mean
# 3.1624219446297146
# current ste
# 0.0008617128874006222
# current mean
# 3.1625058707736784
#  85%|████████▌ | 85/100 [00:18<00:03,  4.77it/s]
# current ste
# 0.0008566812574793178
# current mean
# 3.162595395480885
# current ste
# 0.0008513301732326744
# current mean
# 3.1622970436894615
#  87%|████████▋ | 87/100 [00:18<00:02,  4.79it/s]
# current ste
# 0.0008465552235415532
# current mean
# 3.16254342835525
# current ste
# 0.0008413062696939795
# current mean
# 3.1625996096567675
#  89%|████████▉ | 89/100 [00:18<00:02,  4.75it/s]
# current ste
# 0.0008369388056054486
# current mean
# 3.1625595387448087
# current ste
# 0.0008321557653606416
# current mean
# 3.1625998258590697
#  91%|█████████ | 91/100 [00:19<00:01,  4.77it/s]
# current ste
# 0.0008273901041513627
# current mean
# 3.1624464150313494
# current ste
# 0.0008225713108863509
# current mean
# 3.162324633287347
#  93%|█████████▎| 93/100 [00:19<00:01,  4.70it/s]
# current ste
# 0.0008184220680300872
# current mean
# 3.162445801560597
# current ste
# 0.0008144271988485464
# current mean
# 3.162510932760036
#  95%|█████████▌| 95/100 [00:20<00:01,  4.59it/s]
# current ste
# 0.0008101235488658249
# current mean
# 3.16239329890201
# current ste
# 0.0008060168449175065
# current mean
# 3.162480692068736
#  97%|█████████▋| 97/100 [00:20<00:00,  4.47it/s]
# current ste
# 0.0008020056780920547
# current mean
# 3.1624715229899616
# current ste
# 0.0007982789328810204
# current mean
# 3.162579538870831
#  99%|█████████▉| 99/100 [00:21<00:00,  4.59it/s]
# current ste
# 0.0007946619243546226
# current mean
# 3.1626397311085404
# current ste
# 0.0007912314956545678
# current mean
# 3.162829592227936
# 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]
#   1%|          | 1/100 [00:00<00:22,  4.38it/s]
# current ste
# 0.008064852293970302
# current mean
# 3.156916618347168
# current ste
# 0.0056197209511104195
# current mean
# 3.1644757986068726
#   3%|▎         | 3/100 [00:00<00:22,  4.34it/s]
# current ste
# 0.004558384745890206
# current mean
# 3.1614696979522705
# current ste
# 0.003941973362937302
# current mean
# 3.1607322096824646
#   5%|▌         | 5/100 [00:01<00:21,  4.35it/s]
# current ste
# 0.003472421143949098
# current mean
# 3.1607339859008787
# current ste
# 0.0031910727327722254
# current mean
# 3.1627416610717773
#   7%|▋         | 7/100 [00:01<00:20,  4.57it/s]
# current ste
# 0.0029543806145146557
# current mean
# 3.1646690709250316
# current ste
# 0.0027825568180598233
# current mean
# 3.1656841933727264
#   9%|▉         | 9/100 [00:01<00:19,  4.62it/s]
# current ste
# 0.0026229418737525735
# current mean
# 3.165440215004815
# current ste
# 0.002483075692522059
# current mean
# 3.1656248331069947
#  11%|█         | 11/100 [00:02<00:19,  4.67it/s]
# current ste
# 0.002366394948198038
# current mean
# 3.1639363982460718
# current ste
# 0.002261931108926087
# current mean
# 3.1655385494232178
#  13%|█▎        | 13/100 [00:02<00:18,  4.64it/s]
# current ste
# 0.0021829602379298068
# current mean
# 3.166244103358342
# current ste
# 0.0021105994621083797
# current mean
# 3.1656652348382135
#  15%|█▌        | 15/100 [00:03<00:18,  4.65it/s]
# current ste
# 0.002038998305869931
# current mean
# 3.165592686335246
# current ste
# 0.0019767885289756417
# current mean
# 3.165157333016396
#  17%|█▋        | 17/100 [00:03<00:18,  4.60it/s]
# current ste
# 0.001921611372926737
# current mean
# 3.16529393196106
# current ste
# 0.001868026411219406
# current mean
# 3.164558953709073
#  19%|█▉        | 19/100 [00:04<00:17,  4.51it/s]
# current ste
# 0.001819239701411253
# current mean
# 3.16354062682704
# current ste
# 0.001770622815087278
# current mean
# 3.1631552100181586
#  21%|██        | 21/100 [00:04<00:17,  4.59it/s]
# current ste
# 0.0017258531809746134
# current mean
# 3.1632283188047867
# current ste
# 0.0016858237693869029
# current mean
# 3.162207570942966
#  23%|██▎       | 23/100 [00:05<00:16,  4.59it/s]
# current ste
# 0.001647125440361161
# current mean
# 3.1618529920992646
# current ste
# 0.0016121065652201791
# current mean
# 3.1612663964430494
#  25%|██▌       | 25/100 [00:05<00:16,  4.52it/s]
# current ste
# 0.0015815434585467899
# current mean
# 3.1622937583923343
# current ste
# 0.0015482380457199393
# current mean
# 3.162277753536518
#  27%|██▋       | 27/100 [00:05<00:16,  4.46it/s]
# current ste
# 0.001523119651099261
# current mean
# 3.162411212921143
# current ste
# 0.0014959980226412037
# current mean
# 3.1626978772027154
#  29%|██▉       | 29/100 [00:06<00:15,  4.50it/s]
# current ste
# 0.0014721967285434125
# current mean
# 3.162733974127934
# current ste
# 0.0014473494706367272
# current mean
# 3.1631400108337404
#  31%|███       | 31/100 [00:06<00:15,  4.59it/s]
# current ste
# 0.001426119304961857
# current mean
# 3.1627132738790205
# current ste
# 0.0014021886631646993
# current mean
# 3.162860684096813
#  33%|███▎      | 33/100 [00:07<00:14,  4.61it/s]
# current ste
# 0.0013790015861364026
# current mean
# 3.1628954627297143
# current ste
# 0.0013589003296819522
# current mean
# 3.1627324468949265
#  35%|███▌      | 35/100 [00:07<00:14,  4.63it/s]
# current ste
# 0.0013401197813889898
# current mean
# 3.162846796853202
# current ste
# 0.0013221752037072265
# current mean
# 3.1627943846914506
#  37%|███▋      | 37/100 [00:08<00:13,  4.81it/s]
# current ste
# 0.0013035325532983525
# current mean
# 3.1627141140602735
# current ste
# 0.0012850283177999592
# current mean
# 3.162529248940318
#  39%|███▉      | 39/100 [00:08<00:12,  4.85it/s]
# current ste
# 0.0012688994372463045
# current mean
# 3.162734612440452
# current ste
# 0.0012548114000861406
# current mean
# 3.162655740976334
#  41%|████      | 41/100 [00:08<00:12,  4.90it/s]
# current ste
# 0.0012385339751196413
# current mean
# 3.162933582212867
# current ste
# 0.0012248972684113827
# current mean
# 3.162786551884243
#  43%|████▎     | 43/100 [00:09<00:11,  4.83it/s]
# current ste
# 0.0012119946275243522
# current mean
# 3.1627604018810187
# current ste
# 0.001196672282721288
# current mean
# 3.162735971537504
#  45%|████▌     | 45/100 [00:09<00:11,  4.87it/s]
# current ste
# 0.001183824999803558
# current mean
# 3.1627326965332037
# current ste
# 0.0011715640413596765
# current mean
# 3.1630896070729135
#  47%|████▋     | 47/100 [00:10<00:10,  4.82it/s]
# current ste
# 0.0011583737162454775
# current mean
# 3.1632990228368887
# current ste
# 0.0011462825331255185
# current mean
# 3.163401141762734
#  49%|████▉     | 49/100 [00:10<00:10,  4.70it/s]
# current ste
# 0.0011345747126891936
# current mean
# 3.1632622942632564
# current ste
# 0.0011248165472777277
# current mean
# 3.1634558725357063
#  51%|█████     | 51/100 [00:11<00:10,  4.58it/s]
# current ste
# 0.0011123283003500282
# current mean
# 3.1631656581280283
# current ste
# 0.001100695896452992
# current mean
# 3.16282601081408
#  53%|█████▎    | 53/100 [00:11<00:10,  4.61it/s]
# current ste
# 0.0010897713428223862
# current mean
# 3.1625042636439487
# current ste
# 0.0010788835716860992
# current mean
# 3.162604301064103
#  55%|█████▌    | 55/100 [00:11<00:09,  4.56it/s]
# current ste
# 0.0010700707016192122
# current mean
# 3.1630746104500513
# current ste
# 0.0010606883973733221
# current mean
# 3.1627602449485237
#  57%|█████▋    | 57/100 [00:12<00:09,  4.58it/s]
# current ste
# 0.0010502155984196122
# current mean
# 3.162247176755939
# current ste
# 0.001041613604852185
# current mean
# 3.1625456522251003
#  59%|█████▉    | 59/100 [00:12<00:08,  4.70it/s]
# current ste
# 0.0010324606455587436
# current mean
# 3.162322808120211
# current ste
# 0.0010237866082588151
# current mean
# 3.1623236497243252
#  61%|██████    | 61/100 [00:13<00:08,  4.62it/s]
# current ste
# 0.0010154981828182428
# current mean
# 3.162372526575308
# current ste
# 0.0010066772135434174
# current mean
# 3.162363944515106
#  63%|██████▎   | 63/100 [00:13<00:08,  4.58it/s]
# current ste
# 0.000998498344057437
# current mean
# 3.162349996112643
# current ste
# 0.000990446297405492
# current mean
# 3.162229537963868
#  65%|██████▌   | 65/100 [00:14<00:07,  4.71it/s]
# current ste
# 0.000981653716561492
# current mean
# 3.1622506398421075
# current ste
# 0.0009761191713571941
# current mean
# 3.1626185756741156
#  67%|██████▋   | 67/100 [00:14<00:07,  4.66it/s]
# current ste
# 0.0009695619126937034
# current mean
# 3.1626490657009305
# current ste
# 0.0009623443711395861
# current mean
# 3.1628417022088002
#  69%|██████▉   | 69/100 [00:14<00:06,  4.60it/s]
# current ste
# 0.000955277241093398
# current mean
# 3.162815487903098
# current ste
# 0.0009488811116753703
# current mean
# 3.1625735419137144
#  71%|███████   | 71/100 [00:15<00:06,  4.62it/s]
# current ste
# 0.0009425286668858923
# current mean
# 3.1625853860881974
# current ste
# 0.0009358325196634789
# current mean
# 3.162324912018247
#  73%|███████▎  | 73/100 [00:15<00:05,  4.64it/s]
# current ste
# 0.0009294872365007702
# current mean
# 3.162412617304555
# current ste
# 0.0009227015144970169
# current mean
# 3.162390112876893
#  75%|███████▌  | 75/100 [00:16<00:05,  4.69it/s]
# current ste
# 0.0009166275888873092
# current mean
# 3.162388801574708
# current ste
# 0.0009103893245363883
# current mean
# 3.1622332020809782
#  77%|███████▋  | 77/100 [00:16<00:04,  4.68it/s]
# current ste
# 0.0009041854256245961
# current mean
# 3.162220886775426
# current ste
# 0.0008980660644162304
# current mean
# 3.1621802739607987
#  79%|███████▉  | 79/100 [00:17<00:04,  4.64it/s]
# current ste
# 0.0008920143476580289
# current mean
# 3.1619873559927645
# current ste
# 0.0008863766481447418
# current mean
# 3.161919310688973
#  81%|████████  | 81/100 [00:17<00:04,  4.67it/s]
# current ste
# 0.0008809749021333075
# current mean
# 3.161860557250035
# current ste
# 0.0008755781517200569
# current mean
# 3.1618314719781644
#  83%|████████▎ | 83/100 [00:17<00:03,  4.66it/s]
# current ste
# 0.0008703865430375187
# current mean
# 3.1616592119975264
# current ste
# 0.0008651907411880281
# current mean
# 3.1613781736010598
#  85%|████████▌ | 85/100 [00:18<00:03,  4.67it/s]
# current ste
# 0.0008596633046357552
# current mean
# 3.161135768890381
# current ste
# 0.0008547284673327037
# current mean
# 3.161285175833591
#  87%|████████▋ | 87/100 [00:18<00:02,  4.71it/s]
# current ste
# 0.000850049782944401
# current mean
# 3.1613071841755134
# current ste
# 0.0008448112808719777
# current mean
# 3.161356110464443
#  89%|████████▉ | 89/100 [00:19<00:02,  4.71it/s]
# current ste
# 0.0008404161533488375
# current mean
# 3.1611297639568203
# current ste
# 0.0008352340159738757
# current mean
# 3.161153337690566
#  91%|█████████ | 91/100 [00:19<00:01,  4.72it/s]
# current ste
# 0.0008308923115744342
# current mean
# 3.1610748060457006
# current ste
# 0.0008265414214930148
# current mean
# 3.1611263544663144
#  93%|█████████▎| 93/100 [00:20<00:01,  4.74it/s]
# current ste
# 0.000821906112560399
# current mean
# 3.1611873719000054
# current ste
# 0.000817122191051075
# current mean
# 3.161111882392397
#  95%|█████████▌| 95/100 [00:20<00:01,  4.74it/s]
# current ste
# 0.000813486516617415
# current mean
# 3.161286750592684
# current ste
# 0.000809468758874275
# current mean
# 3.1612167532245325
#  97%|█████████▋| 97/100 [00:20<00:00,  4.73it/s]
# current ste
# 0.0008051849038255373
# current mean
# 3.1612245667841026
# current ste
# 0.0008010826261479321
# current mean
# 3.16139249412381
#  99%|█████████▉| 99/100 [00:21<00:00,  4.71it/s]
# current ste
# 0.0007969054755204484
# current mean
# 3.161447590047664
# current ste
# 0.0007928268830749395
# current mean
# 3.1615463995933544
# 100%|██████████| 100/100 [00:21<00:00,  4.65it/s]
