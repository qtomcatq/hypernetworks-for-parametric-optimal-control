# %%
#from bokeh.plotting import figure
#from bokeh.io import show
#import casadi as ca
import numpy as np
import pdb
#from hilo_mpc import Model, NMPC, UKF, EKF, KF
#from casadi import *


import fire
import matplotlib.pyplot as plt
import torch
import torch.optim.swa_utils as swa_utils
import torchcde
import torchsde
from torch import nn
import copy
import matplotlib.pyplot as plt
from torch import profiler
from tqdm import tqdm
import numpy as np
from typing import Sequence
import pdb
from torchdiffeq import odeint
from scipy.linalg import expm
is_cuda = torch.cuda.is_available()
device = 'cuda' if is_cuda else 'cpu'
import psutil
import os
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) 
sys.path.append(project_root)  # Add folder_a to sys.path
sys.path.append(os.path.join(project_root, '..', 'Networks'))  # Add folder_b to sys.path
from Networks.utils import lqr, Kgain, batchsize_selector,get_coef_grid,generate_cogwheel_matrices, grammian,vt, grammian_array

# %%
# %store -r A
# %store -r B
# %store -r x00

# %%
nsteps=1512
total=1
dt=total/nsteps
N=np.shape(x00)[0]
A=0.75*A
Ac = A*dt + np.eye(A.shape[0])
Bc = B*dt

#print (Ac,Bc)

Qfc = np.eye(N)
Q = 0 *Qfc
Rc = 0.0001
R = Rc*np.eye(B.shape[1])*dt
print(A)
print(B)
x00=x00#+np.array([0.25,0.25])
print(x00)
print(R)
W=grammian(A,B,total)
W_arr=grammian_array(A,B,total)
# Out:
# [[0.75 0.  ]
#  [0.75 0.  ]]
# [[1]
#  [0]]
# [1.  0.5]
# [[6.61375661e-08]]

# %%
contenergy = []
toterrors = []
totenergy = []
inferrors = []

ste_contenergy=[]
ste_toterrors=[]
ste_totenergy=[]

x0=x00
rng=10
desired_state_xf=0*x00

for j in tqdm(range(0,1)):
    
    for i in tqdm(range(0,1)):
        
        gamma=j/10 
        omega=i/10
        print("diffusion noise")
        print(gamma)
        print("observation noise")
        print(omega)
        if j>0 and i>0:

            print('estimating kalman gain')
            kalman_gain=Kgain(Ac,Bc,omega,gamma,x00, nsteps,total,P0)
           
        cycle_tenergy=[]
        cycle_errors =[]
        cycle_cenergy=[]
        cycle_inferrs=[]
        
        action_seq=[]
        iter = batchsize_selector(i,j)
 
        iter=1
        energy=0
        inferr=0
        
        x_ini=np.tile(x00,(iter,1))
        x_ini=x_ini
        desired_state_xf=0*x_ini
        actual_state_x, x1 = x_ini, x_ini
        
        for l in (range(nsteps)):
      
            state_error = x1 - desired_state_xf                
            inf_error=actual_state_x-x1
            inf = np.linalg.norm(inf_error, axis=1)

            t=l*dt
            #A1=expm(A*(total-t))
            A1= expm(A*(total))
            A2=expm(np.transpose(A)*(total-t))
       
            v1=desired_state_xf -np.einsum("ij, kj -> ki", A1, x_ini)
            
            prod=np.matmul(np.matmul(B,np.transpose(B)),np.matmul(A2,np.linalg.pinv(W)))
            action=np.einsum("ij, kj -> ki", prod, v1)
          
            action_seq.append(action*dt)
        
            actual_state_x =  np.einsum("ij, kj -> ki", Ac, actual_state_x) + action*dt  
    
            x1 = actual_state_x
            
                
            
            energy+=  np.mean(np.einsum("kj,kj->k", action,np.einsum("ij, kj -> ki", np.eye(B.shape[1])*dt, action)))
            
                      
            inferr+=dt*np.mean(inf**2)             
            real_error=actual_state_x - desired_state_xf
            sem = np.mean(np.sum(real_error**2,axis=1))
  
            ener=np.squeeze(np.asarray(energy)) 
   
        contenergy.append(energy) 
        toterrors.append(sem)
        totenergy.append(energy+sem)  
        inferrors.append(inferr)

        print(energy)
        print(sem)
        print(energy+sem)
        print(inferr)
        
        
        
       

    
t = np.linspace(0, rng, rng)    
print("control energy")    
print(contenergy)
print("distance")
print(toterrors)
print("tot energy")
print(totenergy)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# diffusion noise
# 0.0
# observation noise
# 0.0
# 100%|██████████| 1/1 [00:00<00:00,  4.36it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
# 18.550537066184408
# 7.401355463832996e-05
# 18.550611079739046
# 0.0
# control energy
# [18.550537066184408]
# distance
# [7.401355463832996e-05]
# tot energy
# [18.550611079739046]

# %%
action_seq
# Out:
# [array([[-0.01598218,  0.        ]]),
#  array([[-0.0159026,  0.       ]]),
#  array([[-0.01582317,  0.        ]]),
#  array([[-0.0157439,  0.       ]]),
#  array([[-0.01566478,  0.        ]]),
#  array([[-0.01558582,  0.        ]]),
#  array([[-0.01550701,  0.        ]]),
#  array([[-0.01542835,  0.        ]]),
#  array([[-0.01534985,  0.        ]]),
#  array([[-0.0152715,  0.       ]]),
#  array([[-0.01519331,  0.        ]]),
#  array([[-0.01511526,  0.        ]]),
#  array([[-0.01503737,  0.        ]]),
#  array([[-0.01495963,  0.        ]]),
#  array([[-0.01488205,  0.        ]]),
#  array([[-0.01480461,  0.        ]]),
#  array([[-0.01472733,  0.        ]]),
#  array([[-0.01465019,  0.        ]]),
#  array([[-0.01457321,  0.        ]]),
#  array([[-0.01449638,  0.        ]]),
#  array([[-0.01441969,  0.        ]]),
#  array([[-0.01434316,  0.        ]]),
#  array([[-0.01426677,  0.        ]]),
#  array([[-0.01419054,  0.        ]]),
#  array([[-0.01411445,  0.        ]]),
#  array([[-0.01403852,  0.        ]]),
#  array([[-0.01396273,  0.        ]]),
#  array([[-0.01388708,  0.        ]]),
#  array([[-0.01381159,  0.        ]]),
#  array([[-0.01373624,  0.        ]]),
#  array([[-0.01366104,  0.        ]]),
#  array([[-0.01358599,  0.        ]]),
#  array([[-0.01351108,  0.        ]]),
#  array([[-0.01343632,  0.        ]]),
#  array([[-0.01336171,  0.        ]]),
#  array([[-0.01328724,  0.        ]]),
#  array([[-0.01321291,  0.        ]]),
#  array([[-0.01313873,  0.        ]]),
#  array([[-0.0130647,  0.       ]]),
#  array([[-0.01299081,  0.        ]]),
#  array([[-0.01291706,  0.        ]]),
#  array([[-0.01284346,  0.        ]]),
#  array([[-0.01277,  0.     ]]),
#  array([[-0.01269669,  0.        ]]),
#  array([[-0.01262352,  0.        ]]),
#  array([[-0.01255049,  0.        ]]),
#  array([[-0.0124776,  0.       ]]),
#  array([[-0.01240486,  0.        ]]),
#  array([[-0.01233226,  0.        ]]),
#  array([[-0.0122598,  0.       ]]),
#  array([[-0.01218748,  0.        ]]),
#  array([[-0.0121153,  0.       ]]),
#  array([[-0.01204326,  0.        ]]),
#  array([[-0.01197136,  0.        ]]),
#  array([[-0.01189961,  0.        ]]),
#  array([[-0.01182799,  0.        ]]),
#  array([[-0.01175651,  0.        ]]),
#  array([[-0.01168518,  0.        ]]),
#  array([[-0.01161398,  0.        ]]),
#  array([[-0.01154292,  0.        ]]),
#  array([[-0.011472,  0.      ]]),
#  array([[-0.01140122,  0.        ]]),
#  array([[-0.01133057,  0.        ]]),
#  array([[-0.01126007,  0.        ]]),
#  array([[-0.0111897,  0.       ]]),
#  array([[-0.01111947,  0.        ]]),
#  array([[-0.01104937,  0.        ]]),
#  array([[-0.01097942,  0.        ]]),
#  array([[-0.0109096,  0.       ]]),
#  array([[-0.01083991,  0.        ]]),
#  array([[-0.01077036,  0.        ]]),
#  array([[-0.01070095,  0.        ]]),
#  array([[-0.01063167,  0.        ]]),
#  array([[-0.01056253,  0.        ]]),
#  array([[-0.01049352,  0.        ]]),
#  array([[-0.01042465,  0.        ]]),
#  array([[-0.01035591,  0.        ]]),
#  array([[-0.01028731,  0.        ]]),
#  array([[-0.01021884,  0.        ]]),
#  array([[-0.0101505,  0.       ]]),
#  array([[-0.0100823,  0.       ]]),
#  array([[-0.01001422,  0.        ]]),
#  array([[-0.00994629,  0.        ]]),
#  array([[-0.00987848,  0.        ]]),
#  array([[-0.00981081,  0.        ]]),
#  array([[-0.00974327,  0.        ]]),
#  array([[-0.00967586,  0.        ]]),
#  array([[-0.00960858,  0.        ]]),
#  array([[-0.00954144,  0.        ]]),
#  array([[-0.00947442,  0.        ]]),
#  array([[-0.00940754,  0.        ]]),
#  array([[-0.00934078,  0.        ]]),
#  array([[-0.00927416,  0.        ]]),
#  array([[-0.00920767,  0.        ]]),
#  array([[-0.0091413,  0.       ]]),
#  array([[-0.00907507,  0.        ]]),
#  array([[-0.00900896,  0.        ]]),
#  array([[-0.00894299,  0.        ]]),
#  array([[-0.00887714,  0.        ]]),
#  array([[-0.00881142,  0.        ]]),
#  array([[-0.00874583,  0.        ]]),
#  array([[-0.00868037,  0.        ]]),
#  array([[-0.00861503,  0.        ]]),
#  array([[-0.00854982,  0.        ]]),
#  array([[-0.00848474,  0.        ]]),
#  array([[-0.00841979,  0.        ]]),
#  array([[-0.00835496,  0.        ]]),
#  array([[-0.00829026,  0.        ]]),
#  array([[-0.00822569,  0.        ]]),
#  array([[-0.00816124,  0.        ]]),
#  array([[-0.00809692,  0.        ]]),
#  array([[-0.00803272,  0.        ]]),
#  array([[-0.00796865,  0.        ]]),
#  array([[-0.00790471,  0.        ]]),
#  array([[-0.00784089,  0.        ]]),
#  array([[-0.00777719,  0.        ]]),
#  array([[-0.00771362,  0.        ]]),
#  array([[-0.00765017,  0.        ]]),
#  array([[-0.00758684,  0.        ]]),
#  array([[-0.00752364,  0.        ]]),
#  array([[-0.00746056,  0.        ]]),
#  array([[-0.00739761,  0.        ]]),
#  array([[-0.00733478,  0.        ]]),
#  array([[-0.00727207,  0.        ]]),
#  array([[-0.00720948,  0.        ]]),
#  array([[-0.00714701,  0.        ]]),
#  array([[-0.00708467,  0.        ]]),
#  array([[-0.00702245,  0.        ]]),
#  array([[-0.00696035,  0.        ]]),
#  array([[-0.00689837,  0.        ]]),
#  array([[-0.00683651,  0.        ]]),
#  array([[-0.00677478,  0.        ]]),
#  array([[-0.00671316,  0.        ]]),
#  array([[-0.00665166,  0.        ]]),
#  array([[-0.00659029,  0.        ]]),
#  array([[-0.00652903,  0.        ]]),
#  array([[-0.00646789,  0.        ]]),
#  array([[-0.00640687,  0.        ]]),
#  array([[-0.00634598,  0.        ]]),
#  array([[-0.0062852,  0.       ]]),
#  array([[-0.00622453,  0.        ]]),
#  array([[-0.00616399,  0.        ]]),
#  array([[-0.00610357,  0.        ]]),
#  array([[-0.00604326,  0.        ]]),
#  array([[-0.00598307,  0.        ]]),
#  array([[-0.005923,  0.      ]]),
#  array([[-0.00586304,  0.        ]]),
#  array([[-0.00580321,  0.        ]]),
#  array([[-0.00574348,  0.        ]]),
#  array([[-0.00568388,  0.        ]]),
#  array([[-0.00562439,  0.        ]]),
#  array([[-0.00556502,  0.        ]]),
#  array([[-0.00550576,  0.        ]]),
#  array([[-0.00544662,  0.        ]]),
#  array([[-0.0053876,  0.       ]]),
#  array([[-0.00532869,  0.        ]]),
#  array([[-0.00526989,  0.        ]]),
#  array([[-0.00521121,  0.        ]]),
#  array([[-0.00515265,  0.        ]]),
#  array([[-0.00509419,  0.        ]]),
#  array([[-0.00503586,  0.        ]]),
#  array([[-0.00497763,  0.        ]]),
#  array([[-0.00491952,  0.        ]]),
#  array([[-0.00486153,  0.        ]]),
#  array([[-0.00480364,  0.        ]]),
#  array([[-0.00474587,  0.        ]]),
#  array([[-0.00468821,  0.        ]]),
#  array([[-0.00463067,  0.        ]]),
#  array([[-0.00457324,  0.        ]]),
#  array([[-0.00451591,  0.        ]]),
#  array([[-0.00445871,  0.        ]]),
#  array([[-0.00440161,  0.        ]]),
#  array([[-0.00434462,  0.        ]]),
#  array([[-0.00428775,  0.        ]]),
#  array([[-0.00423098,  0.        ]]),
#  array([[-0.00417433,  0.        ]]),
#  array([[-0.00411779,  0.        ]]),
#  array([[-0.00406135,  0.        ]]),
#  array([[-0.00400503,  0.        ]]),
#  array([[-0.00394882,  0.        ]]),
#  array([[-0.00389272,  0.        ]]),
#  array([[-0.00383672,  0.        ]]),
#  array([[-0.00378084,  0.        ]]),
#  array([[-0.00372506,  0.        ]]),
#  array([[-0.0036694,  0.       ]]),
#  array([[-0.00361384,  0.        ]]),
#  array([[-0.00355839,  0.        ]]),
#  array([[-0.00350305,  0.        ]]),
#  array([[-0.00344782,  0.        ]]),
#  array([[-0.00339269,  0.        ]]),
#  array([[-0.00333768,  0.        ]]),
#  array([[-0.00328277,  0.        ]]),
#  array([[-0.00322796,  0.        ]]),
#  array([[-0.00317327,  0.        ]]),
#  array([[-0.00311868,  0.        ]]),
#  array([[-0.00306419,  0.        ]]),
#  array([[-0.00300982,  0.        ]]),
#  array([[-0.00295555,  0.        ]]),
#  array([[-0.00290138,  0.        ]]),
#  array([[-0.00284732,  0.        ]]),
#  array([[-0.00279337,  0.        ]]),
#  array([[-0.00273952,  0.        ]]),
#  array([[-0.00268578,  0.        ]]),
#  array([[-0.00263214,  0.        ]]),
#  array([[-0.00257861,  0.        ]]),
#  array([[-0.00252518,  0.        ]]),
#  array([[-0.00247185,  0.        ]]),
#  array([[-0.00241863,  0.        ]]),
#  array([[-0.00236552,  0.        ]]),
#  array([[-0.0023125,  0.       ]]),
#  array([[-0.00225959,  0.        ]]),
#  array([[-0.00220679,  0.        ]]),
#  array([[-0.00215408,  0.        ]]),
#  array([[-0.00210148,  0.        ]]),
#  array([[-0.00204898,  0.        ]]),
#  array([[-0.00199659,  0.        ]]),
#  array([[-0.00194429,  0.        ]]),
#  array([[-0.0018921,  0.       ]]),
#  array([[-0.00184001,  0.        ]]),
#  array([[-0.00178803,  0.        ]]),
#  array([[-0.00173614,  0.        ]]),
#  array([[-0.00168435,  0.        ]]),
#  array([[-0.00163267,  0.        ]]),
#  array([[-0.00158109,  0.        ]]),
#  array([[-0.0015296,  0.       ]]),
#  array([[-0.00147822,  0.        ]]),
#  array([[-0.00142694,  0.        ]]),
#  array([[-0.00137576,  0.        ]]),
#  array([[-0.00132467,  0.        ]]),
#  array([[-0.00127369,  0.        ]]),
#  array([[-0.00122281,  0.        ]]),
#  array([[-0.00117203,  0.        ]]),
#  array([[-0.00112134,  0.        ]]),
#  array([[-0.00107076,  0.        ]]),
#  array([[-0.00102027,  0.        ]]),
#  array([[-0.00096988,  0.        ]]),
#  array([[-0.00091959,  0.        ]]),
#  array([[-0.0008694,  0.       ]]),
#  array([[-0.0008193,  0.       ]]),
#  array([[-0.00076931,  0.        ]]),
#  array([[-0.00071941,  0.        ]]),
#  array([[-0.00066961,  0.        ]]),
#  array([[-0.0006199,  0.       ]]),
#  array([[-0.0005703,  0.       ]]),
#  array([[-0.00052079,  0.        ]]),
#  array([[-0.00047137,  0.        ]]),
#  array([[-0.00042205,  0.        ]]),
#  array([[-0.00037283,  0.        ]]),
#  array([[-0.00032371,  0.        ]]),
#  array([[-0.00027468,  0.        ]]),
#  array([[-0.00022575,  0.        ]]),
#  array([[-0.00017691,  0.        ]]),
#  array([[-0.00012816,  0.        ]]),
#  array([[-7.9516567e-05,  0.0000000e+00]]),
#  array([[-3.09637445e-05,  0.00000000e+00]]),
#  array([[1.74943408e-05, 0.00000000e+00]]),
#  array([[6.58578737e-05, 0.00000000e+00]]),
#  array([[0.00011413, 0.        ]]),
#  array([[0.0001623, 0.       ]]),
#  array([[0.00021038, 0.        ]]),
#  array([[0.00025837, 0.        ]]),
#  array([[0.00030626, 0.        ]]),
#  array([[0.00035406, 0.        ]]),
#  array([[0.00040177, 0.        ]]),
#  array([[0.00044938, 0.        ]]),
#  array([[0.00049691, 0.        ]]),
#  array([[0.00054433, 0.        ]]),
#  array([[0.00059167, 0.        ]]),
#  array([[0.00063891, 0.        ]]),
#  array([[0.00068606, 0.        ]]),
#  array([[0.00073312, 0.        ]]),
#  array([[0.00078009, 0.        ]]),
#  array([[0.00082696, 0.        ]]),
#  array([[0.00087375, 0.        ]]),
#  array([[0.00092044, 0.        ]]),
#  array([[0.00096704, 0.        ]]),
#  array([[0.00101355, 0.        ]]),
#  array([[0.00105997, 0.        ]]),
#  array([[0.0011063, 0.       ]]),
#  array([[0.00115254, 0.        ]]),
#  array([[0.00119869, 0.        ]]),
#  array([[0.00124475, 0.        ]]),
#  array([[0.00129072, 0.        ]]),
#  array([[0.0013366, 0.       ]]),
#  array([[0.00138239, 0.        ]]),
#  array([[0.00142809, 0.        ]]),
#  array([[0.0014737, 0.       ]]),
#  array([[0.00151922, 0.        ]]),
#  array([[0.00156465, 0.        ]]),
#  array([[0.00161, 0.     ]]),
#  array([[0.00165526, 0.        ]]),
#  array([[0.00170042, 0.        ]]),
#  array([[0.0017455, 0.       ]]),
#  array([[0.0017905, 0.       ]]),
#  array([[0.0018354, 0.       ]]),
#  array([[0.00188022, 0.        ]]),
#  array([[0.00192494, 0.        ]]),
#  array([[0.00196959, 0.        ]]),
#  array([[0.00201414, 0.        ]]),
#  array([[0.00205861, 0.        ]]),
#  array([[0.00210299, 0.        ]]),
#  array([[0.00214728, 0.        ]]),
#  array([[0.00219149, 0.        ]]),
#  array([[0.00223561, 0.        ]]),
#  array([[0.00227965, 0.        ]]),
#  array([[0.0023236, 0.       ]]),
#  array([[0.00236746, 0.        ]]),
#  array([[0.00241124, 0.        ]]),
#  array([[0.00245493, 0.        ]]),
#  array([[0.00249854, 0.        ]]),
#  array([[0.00254206, 0.        ]]),
#  array([[0.0025855, 0.       ]]),
#  array([[0.00262885, 0.        ]]),
#  array([[0.00267212, 0.        ]]),
#  array([[0.00271531, 0.        ]]),
#  array([[0.0027584, 0.       ]]),
#  array([[0.00280142, 0.        ]]),
#  array([[0.00284435, 0.        ]]),
#  array([[0.0028872, 0.       ]]),
#  array([[0.00292996, 0.        ]]),
#  array([[0.00297264, 0.        ]]),
#  array([[0.00301524, 0.        ]]),
#  array([[0.00305776, 0.        ]]),
#  array([[0.00310019, 0.        ]]),
#  array([[0.00314254, 0.        ]]),
#  array([[0.0031848, 0.       ]]),
#  array([[0.00322699, 0.        ]]),
#  array([[0.00326909, 0.        ]]),
#  array([[0.00331111, 0.        ]]),
#  array([[0.00335304, 0.        ]]),
#  array([[0.0033949, 0.       ]]),
#  array([[0.00343667, 0.        ]]),
#  array([[0.00347836, 0.        ]]),
#  array([[0.00351997, 0.        ]]),
#  array([[0.0035615, 0.       ]]),
#  array([[0.00360295, 0.        ]]),
#  array([[0.00364432, 0.        ]]),
#  array([[0.00368561, 0.        ]]),
#  array([[0.00372681, 0.        ]]),
#  array([[0.00376794, 0.        ]]),
#  array([[0.00380898, 0.        ]]),
#  array([[0.00384995, 0.        ]]),
#  array([[0.00389083, 0.        ]]),
#  array([[0.00393164, 0.        ]]),
#  array([[0.00397237, 0.        ]]),
#  array([[0.00401301, 0.        ]]),
#  array([[0.00405358, 0.        ]]),
#  array([[0.00409407, 0.        ]]),
#  array([[0.00413448, 0.        ]]),
#  array([[0.00417481, 0.        ]]),
#  array([[0.00421506, 0.        ]]),
#  array([[0.00425523, 0.        ]]),
#  array([[0.00429533, 0.        ]]),
#  array([[0.00433534, 0.        ]]),
#  array([[0.00437528, 0.        ]]),
#  array([[0.00441514, 0.        ]]),
#  array([[0.00445493, 0.        ]]),
#  array([[0.00449463, 0.        ]]),
#  array([[0.00453426, 0.        ]]),
#  array([[0.00457381, 0.        ]]),
#  array([[0.00461328, 0.        ]]),
#  array([[0.00465268, 0.        ]]),
#  array([[0.004692, 0.      ]]),
#  array([[0.00473124, 0.        ]]),
#  array([[0.00477041, 0.        ]]),
#  array([[0.0048095, 0.       ]]),
#  array([[0.00484851, 0.        ]]),
#  array([[0.00488745, 0.        ]]),
#  array([[0.00492631, 0.        ]]),
#  array([[0.00496509, 0.        ]]),
#  array([[0.0050038, 0.       ]]),
#  array([[0.00504244, 0.        ]]),
#  array([[0.005081, 0.      ]]),
#  array([[0.00511948, 0.        ]]),
#  array([[0.00515789, 0.        ]]),
#  array([[0.00519622, 0.        ]]),
#  array([[0.00523448, 0.        ]]),
#  array([[0.00527266, 0.        ]]),
#  array([[0.00531077, 0.        ]]),
#  array([[0.00534881, 0.        ]]),
#  array([[0.00538677, 0.        ]]),
#  array([[0.00542466, 0.        ]]),
#  array([[0.00546247, 0.        ]]),
#  array([[0.00550021, 0.        ]]),
#  array([[0.00553787, 0.        ]]),
#  array([[0.00557547, 0.        ]]),
#  array([[0.00561298, 0.        ]]),
#  array([[0.00565043, 0.        ]]),
#  array([[0.0056878, 0.       ]]),
#  array([[0.0057251, 0.       ]]),
#  array([[0.00576233, 0.        ]]),
#  array([[0.00579948, 0.        ]]),
#  array([[0.00583656, 0.        ]]),
#  array([[0.00587357, 0.        ]]),
#  array([[0.00591051, 0.        ]]),
#  array([[0.00594738, 0.        ]]),
#  array([[0.00598417, 0.        ]]),
#  array([[0.00602089, 0.        ]]),
#  array([[0.00605754, 0.        ]]),
#  array([[0.00609412, 0.        ]]),
#  array([[0.00613062, 0.        ]]),
#  array([[0.00616706, 0.        ]]),
#  array([[0.00620342, 0.        ]]),
#  array([[0.00623972, 0.        ]]),
#  array([[0.00627594, 0.        ]]),
#  array([[0.00631209, 0.        ]]),
#  array([[0.00634817, 0.        ]]),
#  array([[0.00638418, 0.        ]]),
#  array([[0.00642013, 0.        ]]),
#  array([[0.006456, 0.      ]]),
#  array([[0.0064918, 0.       ]]),
#  array([[0.00652753, 0.        ]]),
#  array([[0.00656319, 0.        ]]),
#  array([[0.00659878, 0.        ]]),
#  array([[0.0066343, 0.       ]]),
#  array([[0.00666975, 0.        ]]),
#  array([[0.00670514, 0.        ]]),
#  array([[0.00674045, 0.        ]]),
#  array([[0.0067757, 0.       ]]),
#  array([[0.00681088, 0.        ]]),
#  array([[0.00684598, 0.        ]]),
#  array([[0.00688102, 0.        ]]),
#  array([[0.00691599, 0.        ]]),
#  array([[0.0069509, 0.       ]]),
#  array([[0.00698573, 0.        ]]),
#  array([[0.0070205, 0.       ]]),
#  array([[0.0070552, 0.       ]]),
#  array([[0.00708983, 0.        ]]),
#  array([[0.00712439, 0.        ]]),
#  array([[0.00715889, 0.        ]]),
#  array([[0.00719332, 0.        ]]),
#  array([[0.00722768, 0.        ]]),
#  array([[0.00726198, 0.        ]]),
#  array([[0.0072962, 0.       ]]),
#  array([[0.00733037, 0.        ]]),
#  array([[0.00736446, 0.        ]]),
#  array([[0.00739849, 0.        ]]),
#  array([[0.00743245, 0.        ]]),
#  array([[0.00746634, 0.        ]]),
#  array([[0.00750017, 0.        ]]),
#  array([[0.00753394, 0.        ]]),
#  array([[0.00756763, 0.        ]]),
#  array([[0.00760127, 0.        ]]),
#  array([[0.00763483, 0.        ]]),
#  array([[0.00766833, 0.        ]]),
#  array([[0.00770177, 0.        ]]),
#  array([[0.00773514, 0.        ]]),
#  array([[0.00776844, 0.        ]]),
#  array([[0.00780168, 0.        ]]),
#  array([[0.00783486, 0.        ]]),
#  array([[0.00786797, 0.        ]]),
#  array([[0.00790101, 0.        ]]),
#  array([[0.00793399, 0.        ]]),
#  array([[0.00796691, 0.        ]]),
#  array([[0.00799976, 0.        ]]),
#  array([[0.00803255, 0.        ]]),
#  array([[0.00806528, 0.        ]]),
#  array([[0.00809794, 0.        ]]),
#  array([[0.00813053, 0.        ]]),
#  array([[0.00816307, 0.        ]]),
#  array([[0.00819554, 0.        ]]),
#  array([[0.00822794, 0.        ]]),
#  array([[0.00826029, 0.        ]]),
#  array([[0.00829257, 0.        ]]),
#  array([[0.00832478, 0.        ]]),
#  array([[0.00835694, 0.        ]]),
#  array([[0.00838903, 0.        ]]),
#  array([[0.00842106, 0.        ]]),
#  array([[0.00845302, 0.        ]]),
#  array([[0.00848493, 0.        ]]),
#  array([[0.00851677, 0.        ]]),
#  array([[0.00854855, 0.        ]]),
#  array([[0.00858027, 0.        ]]),
#  array([[0.00861192, 0.        ]]),
#  array([[0.00864352, 0.        ]]),
#  array([[0.00867505, 0.        ]]),
#  array([[0.00870652, 0.        ]]),
#  array([[0.00873793, 0.        ]]),
#  array([[0.00876928, 0.        ]]),
#  array([[0.00880056, 0.        ]]),
#  array([[0.00883179, 0.        ]]),
#  array([[0.00886295, 0.        ]]),
#  array([[0.00889406, 0.        ]]),
#  array([[0.0089251, 0.       ]]),
#  array([[0.00895608, 0.        ]]),
#  array([[0.00898701, 0.        ]]),
#  array([[0.00901787, 0.        ]]),
#  array([[0.00904867, 0.        ]]),
#  array([[0.00907941, 0.        ]]),
#  array([[0.00911009, 0.        ]]),
#  array([[0.00914072, 0.        ]]),
#  array([[0.00917128, 0.        ]]),
#  array([[0.00920178, 0.        ]]),
#  array([[0.00923222, 0.        ]]),
#  array([[0.00926261, 0.        ]]),
#  array([[0.00929293, 0.        ]]),
#  array([[0.0093232, 0.       ]]),
#  array([[0.0093534, 0.       ]]),
#  array([[0.00938355, 0.        ]]),
#  array([[0.00941364, 0.        ]]),
#  array([[0.00944367, 0.        ]]),
#  array([[0.00947364, 0.        ]]),
#  array([[0.00950355, 0.        ]]),
#  array([[0.00953341, 0.        ]]),
#  array([[0.0095632, 0.       ]]),
#  array([[0.00959294, 0.        ]]),
#  array([[0.00962262, 0.        ]]),
#  array([[0.00965224, 0.        ]]),
#  array([[0.0096818, 0.       ]]),
#  array([[0.00971131, 0.        ]]),
#  array([[0.00974076, 0.        ]]),
#  array([[0.00977015, 0.        ]])]

# %%
# %store -r totenergy

# %%
cntrl=np.array(contenergy)
cntrl=cntrl.reshape(11,11)

# %%
np.transpose(cntrl)
# Out:
# array([[0.93981956, 0.94623294, 0.96826612, 1.01262383, 1.0672357 ,
#         1.13525565, 1.23616329, 1.34620816, 1.46194067, 1.61105894,
#         1.76164234],
#        [0.93981956, 1.04776161, 1.05820576, 1.10242   , 1.13846908,
#         1.19808761, 1.27605339, 1.36925957, 1.47358022, 1.63180532,
#         1.75264414],
#        [0.93981956, 1.20564294, 1.19633444, 1.21885772, 1.24963772,
#         1.30374403, 1.36137527, 1.44521033, 1.53535135, 1.66019949,
#         1.79776338],
#        [0.93981956, 1.30111481, 1.29997614, 1.32090693, 1.37589274,
#         1.41721738, 1.47313627, 1.55365015, 1.63449187, 1.74153354,
#         1.84650305],
#        [0.93981956, 1.40636315, 1.38105059, 1.40727101, 1.4377323 ,
#         1.48821117, 1.55072444, 1.61634005, 1.68993958, 1.76776387,
#         1.9003641 ],
#        [0.93981956, 1.44244533, 1.43679601, 1.452207  , 1.49880092,
#         1.52802029, 1.57111587, 1.64720907, 1.71921343, 1.81156342,
#         1.89985871],
#        [0.93981956, 1.43405812, 1.45728453, 1.4890942 , 1.51918201,
#         1.54397051, 1.58459007, 1.65335064, 1.73215406, 1.81128801,
#         1.91154885],
#        [0.93981956, 1.44429496, 1.47167036, 1.47783201, 1.51148805,
#         1.54927683, 1.60315666, 1.64355566, 1.73874566, 1.79283737,
#         1.90326994],
#        [0.93981956, 1.45982499, 1.44662931, 1.47759282, 1.49584853,
#         1.52435057, 1.5787862 , 1.62758496, 1.7190958 , 1.77539512,
#         1.87212188],
#        [0.93981956, 1.42386385, 1.42081965, 1.44337684, 1.48217572,
#         1.49562697, 1.55330427, 1.59155986, 1.66858286, 1.71829341,
#         1.82056323],
#        [0.93981956, 1.41277378, 1.39839023, 1.42769631, 1.45316219,
#         1.48062302, 1.53759312, 1.57382291, 1.63615944, 1.69914918,
#         1.77603222]])

# %%
ste_totenergy
# Out:
# [0.0,
#  0.008597564189638288,
#  0.013845273099069456,
#  0.019354100097564716,
#  0.023543240512569914,
#  0.028213496257533513,
#  0.03284902646781433,
#  0.03507712258973467,
#  0.039885641689659315,
#  0.04233054447606892]

# %%
# Out:
# P matrix at the end of the horizon:
# [[0. 0.]
#  [0. 0.]]

# %%
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
# Out:
# array([[0.]])
